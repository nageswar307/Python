# %% [markdown]
# <a href="https://colab.research.google.com/github/nageswar307/Python/blob/main/Day8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = [-10,-20,15,5]

abs(-20)
# Out:
# 20

# %%
large = 0
idx = 0
for index,ele in enumerate(num):
  if abs(ele) > large:
    large = abs(ele)
    idx = index

print(num[idx])
# Out:
# -20

# %%
string = "abc"
for idx,char in enumerate(string):
  print(idx,char)
# Out:
# 0 a
# 1 b
# 2 c

# %%
large = max(num, key = abs)
print(large)
# Out:
# -20

# %%
fruits = ["apple","orange","banana","zig"]
min(fruits,key=len)
# Out:
# 'zig'

# %%
len("apple")
# Out:
# 5

# %%
fruits = ["apple","orange","banana","zig"]

fruits.sort()

print(fruits)
# Out:
# ['apple', 'banana', 'orange', 'zig']

# %%
fruits = ["apple","orange","banana","zig"]

sorted_list = sorted(fruits)

print(sorted_list)
# Out:
# ['apple', 'banana', 'orange', 'zig']

# %%
sorted(fruits,key=len).sort()

# %%
students = [{"name": "raj","score":"90"},
            {"name": "Alice","score":"86"},
            {"name": "Bob","score":"77"}]

# %%
dict1 = {'name': 'raj', 'score': '90'}
dict1["score"]
# Out:
# '90'

# %%
highest_score = 0

for dict1 in students:
  print(dict1)
  print(int(dict1["score"]))
  if int(dict1["score"]) > highest_score:
    highest_score = dict1["score"]
    print(highest_score)

highest_score
# Out:
# {'name': 'raj', 'score': '90'}
# 90
# 90
# {'name': 'Alice', 'score': '86'}
# 86
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-8741ae73f4d4> in <cell line: 3>()
#       4   print(dict1)
#       5   print(int(dict1["score"]))
# ----> 6   if int(dict1["score"]) > highest_score:
#       7     highest_score = dict1["score"]
#       8     print(highest_score)
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %%
students = [{"name": "Alice","score":86,"score2":90},
            {"name": "Bob","score":77,"score2":56},
            {"name": "raj","score":90,"score2":67}]

# %%
max(students, key=lambda student: int(student["score2"]))
# Out:
# {'name': 'Alice', 'score': 86, 'score2': 90}

# %%
sorted(students, key=lambda x: int(x["score"]),reverse=True)
# Out:
# [{'name': 'raj', 'score': '90'},
#  {'name': 'Alice', 'score': '86'},
#  {'name': 'Bob', 'score': '77'}]

# %%
students = [("Bob",77),("raj",90),("Alice",86)]

# %%
sorted(students, key=lambda x:x[0])
# Out:
# [('Alice', 86), ('Bob', 77), ('raj', 90)]

# %%
nums=[
    {"name":"Sreenu","one":1},
    {"name":"Shiva","one":100},
    {"name":"Vijay","one":22}
]
Highest_Score = 0
for dict1 in nums:
    if dict1["one"] >= Highest_Score:
        Highest_Score=dict1["one"]
print(Highest_Score)
# Out:
# 100

# %%
lst = [[1,2,3],
       [2,4,5],[12,56],
       [3,2,8],
       ]

max_sum = 0
index = None

for idx,ele in enumerate(lst):
  if sum(ele) > max_sum:
    max_sum = sum(ele)
    index = idx

print(lst[index])

max_sum
# Out:
# [12, 56]
# 68

# %%
max(lst,key=sum)
# Out:
# [12, 56]

# %%
sorted(lst,key=sum)
# Out:
# [[1, 2, 3], [2, 4, 5], [3, 2, 8], [12, 56]]

# %%
dict1 = {"Charlie": 90,
         "Bob":89,
         "Alice":96}

# %%
sorted(dict1,key=lambda x:dict1[x])
# Out:
# ['Bob', 'Charlie', 'Alice']

# %%
text = '''the cat is on mat.
the cat likes milk.
the cat eats milk.
the mat is on the floor.
One of the best known, and one of the least intelligible, facts of literary history is the lateness, in Western European Literature at any rate, of prose fiction, and the comparative absence, in the two great classical languages, of what we call by that name. It might be an accident, though a rather improbable one, that we have no Greek prose fiction till a time long subsequent to the Christian era, and nothing in Latin at all except the fragments of Petronius and the romance of Apuleius. But it can be no accident, and it is a very momentous fact, that, from the foundation of Greek criticism, "Imitation," that is to say "Fiction" (for it is neither more nor less), was regarded as not merely the inseparable but the constituent property of poetry, even though those who held this were doubtful whether poetry must necessarily be in verse. It is another fact of the greatest importance that the ancients who, in other forms than deliberate prose fiction, try to "tell a story," do not seem to know very well how to do it.

The Odyssey is, indeed, one of the greatest of all stories, it is the original romance of the West; but the Iliad, though a magnificent poem, is not much of a story. Herodotus can tell one, if anybody can, and Plato (or Socrates) evidently could have done so if it had lain in his way: while the Anabasis, though hardly the Cyropædia, shows glimmerings in Xenophon. But otherwise we must come down to Lucian and the East before we find the faculty. So, too, in Latin before the two late writers named above, Ovid is about the only person who is a real story-teller. Virgil makes very little of his story in verse: and it is shocking to think how Livy throws away his chances in prose. No: putting the Petronian fragments aside, Lucian and Apuleius are the only two novelists in the classical languages before about 400 A.D.: and putting aside their odd coincidence of subject, it has to be remembered that Lucian was a Syrian Greek and Apuleius an African Latin. The conquered world was to conquer not only its conqueror, but its conqueror's teacher, in this youngest accomplishment of literary art.

It was probably in all cases, if not certainly, mixed blood that produced the curious development generally called Greek Romance. It is no part of our business to survey, in any detail, the not very numerous but distinctly interesting compositions which range in point of authorship from Longus and Heliodorus, probably at the meeting of the fourth and fifth centuries, to Eustathius in the twelfth. At one time indeed, when we may return to them a little, we shall find them exercising direct and powerful influence on modern European fiction, and so both directly and indirectly on English: but that is a time a good way removed from the actual beginning of our journey. Still, Apollonius of Tyre, which is probably the oldest piece of English prose fiction that we have, is beyond all doubt derived ultimately from a Greek original of this very class: and the class itself is an immense advance, in the novel direction, upon anything that we have before. It is on the one hand essentially a "romance of adventure," and on the other essentially a "love-story"—in senses to which we find little in classical literature to correspond in the one case and still less in the other. Instead of being, like Lucius and the Golden Ass, a tissue of stories essentially unconnected and little more than framed by the main tale, it is, though it may have a few episodes, an example of at least romantic unity throughout, with definite hero and definite heroine, the prominence and importance of the latter being specially noteworthy. It is in fact the first division of literature in which the heroine assumes the position of a protagonist. If it falls short in character, so do even later romances to a great extent: if dialogue is not very accomplished, that also was hardly to be thoroughly developed till the novel proper came into being. In the other two great divisions, incident and description, it is abundantly furnished. And, above all, the two great Romantic motives, Adventure and Love, are quite maturely present in it.

To pass to the deluge, and beyond it, and to come to close quarters with our proper division, the origin of Romance itself is a very debatable subject, or rather it is a subject which the wiser mind will hardly care to debate much. The opinion of the present writer—the result, at least, of many years' reading and thought—is that it is a result of the marriage of the older East and the newer (non-classical) West through the agency of the spread of Christianity and the growth and diffusion of the "Saint's Life." The beginnings of Hagiology itself are very uncertain: but what is certain is that they are very early: and that as the amalgamation or leavening of the Roman world with barbarian material proceeded, the spread of Christianity proceeded likewise. The Vision of St. Paul—one of the earliest examples and the starter it would seem, if not of the whole class of sacred Romances, at any rate of the large subsection devoted to Things after Death—has been put as early as "before 400 A.D." It would probably be difficult to date such legends as those of St. Margaret and St. Catherine too early, having regard to their intrinsic indications: and the vast cycle of Our Lady, though probably later, must have begun long before the modern languages were ready for it, while that of the Cross should be earlier still. And let it be remembered that these Saints' Lives, which are still infinitely good reading, are not in the least confined to homiletic necessities. The jejuneness and woodenness from which the modern religious story too often suffers are in no way chargeable upon all, or even many, of them. They have the widest range of incident—natural as well as supernatural: their touches of nature are indeed extended far beyond mere incident. Purely comic episodes are by no means wanting: and these, like the parallel passages in the dramatising of these very legends, were sure to lead to isolation of them, and to a secular continuation.

But, once more, we must contract the sweep, and quicken the pace to deal not with possible origins, but with actual results—not with Ancient or Transition literature, but with the literature of English in the department first of fiction generally and then, with a third and last narrowing, to the main subject of English fiction in prose.

The very small surviving amount, and the almost completely second-hand character, of Anglo-Saxon literature have combined to frustrate what might have been expected from another characteristic of it—the unusual equality of its verse and prose departments. We have only one—not quite entire but substantive—prose tale in Anglo-Saxon, the version of the famous story of Apollonius of Tyre, which was to be afterwards declined by Chaucer, but attempted by his friend and contemporary Gower, and to be enshrined in the most certain of the Shakespearean "doubtfuls," Pericles. It most honestly gives itself out as a translation (no doubt from the Latin though there was an early Greek original) and it deals briefly with the subject. But as an example of narrative style it is very far indeed from being contemptible: and in passages such as Apollonius' escape from shipwreck, and his wooing of the daughter of Arcestrates, there is something which is different from style, and with which style is not always found in company—that faculty of telling a story which has been already referred to. Nor does this fail in the narrative portions of the prose Saints' Lives and Homilies, especially Aelfric's, which we possess; in fact it is in these last distinctly remarkable—as where Aelfric tells the tale of the monk who spied on St. Cuthbert's seaside devotions. The same faculty is observable in Latin work, not least in Bede's still more famous telling of the Caedmon story, and of the vision of the other world.

But these faculties have better chance of exhibiting themselves in the verse division of our Anglo-Saxon wreckage. Beowulf itself consists of one first-rate story and one second-rate but not despicable tale, hitched together more or less anyhow. The second, with good points, is, for us, negligible: the first is a "yarn" of the primest character. One may look back to the Odyssey itself without finding anything so good, except the adventures of the Golden Ass which had all the story-work of two mightiest literatures behind them. As literature on the other hand, Beowulf may be overpraised: it has been so frequently. But let anybody with the slightest faculty of "conveyance" tell the first part of the story to a tolerably receptive audience, and he will not doubt (unless he is fool enough to set the effect down to his own gifts and graces) about its excellence as such. There is character—not much, but enough to make it more than a mere story of adventure—and adventure enough for anything; there is by no means ineffectual speech—even dialogue—of a kind: and there is some effective and picturesque description. The same faculties reappear in such mere fragments as that of Waldhere and the "Finnsburgh" fight: but they are shown much more fully in the Saints' Lives—best of all in the Andreas, no doubt, but remarkably also (especially considering the slender amount of "happenings") in the Guthlac and the Juliana. In fact the very fragments of Anglo-Saxon poetry, by a sort of approximation which they show to dramatic narrative and which with a few exceptions is far less present in the classics, foretell much more clearly and certainly than in the case of some other foretellings which have been detected in them, the future achievements of English literature in the department of fiction. The Ruin (the finest thing perhaps in all Anglo-Saxon) is a sort of background study for something that might have been much better than The Last Days of Pompeii: and The Complaint of Deor, in its allusion to the adventures of the smith Weland and others, makes one sorry that some one more like the historian of a later and decadent though agreeable Wayland the Smith, had not told us the tale that is now left untold. A crowd of fantastic imaginings or additions, to supply the main substance, and a certain common-sense grasp of actual conditions and circumstances to set them upon, and contrast them with—these are the great requirements of Fiction in life and character. You must mix prose and poetry to get a good romance or even novel. The consciences of the ancients revolted from this mixture of kinds; but there was no such revolt in the earlier moderns, and least of all in our own mediæval forefathers.

So few people are really acquainted with the whole range of Romance (even in English), or with any large part of it, that one may without undue presumption set down in part, if not in whole, to ignorance, a doctrine and position which we must now attack. This is that romance and novel are widely separated from each other; and that the historian of the novel is really straying out of his ground if he meddles with Romance. These are they who would make our proper subject begin with Marivaux and Richardson, or at earliest with Madame de La Fayette, who exclude Bunyan altogether, and sometimes go so far as to question the right of entry to Defoe. But the counter-arguments are numerous: and any one of them would almost suffice by itself. In the first place the idea of the novel arising so late is unnatural and unhistorical: these Melchisedecs without father or mother are not known in literature. In the second a pedantic insistence on the exclusive definition of the novel involves one practical inconvenience which no one, even among those who believe in it, has yet dared to face. You must carry your wall of partition along the road as well as across it: and write separate histories of Novel and Romance for the last two centuries. The present writer can only say that, though he has dared some tough adventures in literary history, he would altogether decline this. Without the help of the ants that succoured Psyche against Venus that heap would indeed be ill to sort.

But there is a third argument, less practical in appearance but bolder and deeper, which is really decisive of the matter, though few seem to have seen it or at least taken it up. The separation of romance and novel—of the story of incident and the story of character and motive—is a mistake logically and psychologically. It is a very old mistake, and it has deceived some of the elect: but a mistake it is. It made even Dr. Johnson think Fielding shallower than Richardson; and it has made people very different from Dr. Johnson think that Count Tolstoi is a greater analyst and master of a more developed humanity than Fielding. As a matter of fact, when you have excogitated two or more human beings out of your own head and have set them to work in the narrative (not the dramatic) way, you have made the novel in posse, if not in esse, from its apparently simplest development, such as Daphnis and Chloe, to its apparently most complex, such as the Kreutzer Sonata or the triumphs of Mr. Meredith. You have started the "Imitation"—the "fiction"—and tout est là. The ancients could do this in the dramatic way admirably, though on few patterns; in the poetical way as admirably, but again not on many. The Middle Ages lost the dramatic way almost entirely, but they actually improved the poetical on its narrative side, and the result was Romance. In every romance there is the germ of a novel and more; there is at least the suggestion and possibility of romance in every novel that deserves the name. In the Tristram story and the Lancelot cycle there are most of the things that the romancer of incident and the novelist of character and motive can want or can use, till the end of the world; and Malory (that "mere compiler" as some pleasantly call him) has put the possibilities of the latter and greater creation so that no one who has eyes can miss them. Nor in the beginning does it much or at all matter whether the vehicle was prose or verse. In fact they mostly wrote in verse because prose was not ready.

In the minor romances and tales (taking English versions only) from Havelok to Beryn there is a whole universe of situation, scenario, opportunity for "business." That they have the dress and the scene-backing of one particular period can matter to no one who has eyes for anything beyond dress and scene-backing. And when we are told that they are apt to run too much into grooves and families, it is sufficient to answer that it really does not lie in the mouth of an age which produces grime-novels, problem-novels, and so forth, as if they had been struck off on a hectograph, possessing the not very exalted gift of varying names and places—to reproach any other age on this score. But we have only limited room here for generalities and still less for controversy; let us turn to our proper work and survey the actual turn-out in fiction—mostly as a result of mere fashion, verse, but partly prose—which the Middle Ages has left us as a contribution to this department of English literature.

It has been said that few people know the treasures of English romance, yet there is little excuse for ignorance of them. It is some century since Ellis's extremely amusing, if sometimes rather prosaic, book put much of the matter before those who will not read originals; to be followed in the same path by Dunlop later, and much later still by the invaluable and delightful Catalogue of [British Museum] Romances by Mr. Ward. It is nearly as long since the collections of Ritson and Weber, soon supplemented by others, and enlarged for the last forty years by the publications of the Early English Text Society, put these originals themselves within the reach of everybody who is not so lazy or so timid as to be disgusted or daunted by a very few actually obsolete words and a rather large proportion of obsolete spellings, which will yield to even the minimum of intelligent attention. Only a very small number (not perhaps including a single one of importance) remain unprinted, though no doubt a few are out of print or difficult to obtain. The quality and variety of the stories told in them are both very considerable, even without making allowance for what has been called the stock character of mediæval composition. That almost all are directly imitated from the French is probable enough, that most are is certain: but this matters, for our purpose, nothing at all. That the imitation was not haphazard or indiscriminate is obvious. Thus, though we have some, we have not very many representatives of the class which was the most numerous of all in France—the chansons de geste or stories of French legendary history, national or family. Except as far as the Saracens are concerned, they would naturally have less interest for English hearers. The Matière de Rome, again—the legends of antiquity—though represented, is not very abundant outside of the universally popular Tale of Troy; and the almost equally popular Alexander legend does not occupy a very large part of them. What is perhaps more remarkable is that until Malory exercised his genius upon "the French book," the more poetical parts of the "matter of Britain" itself do not seem to have been very much written about in English. The preliminary stuff about Merlin and Vortigern exists in several handlings; the foreign campaigns of Arthur seem always (perhaps from national vanity) to have been popular. The "off"-branches of Tristram and Percivale, and not a few of the still more episodic romances of adventures concerning Gawain, Iwain, and other knights, receive attention. The execrable Lonelich or Lovelich, who preceded Malory a little, had of course predecessors in handling the other parts of the Graal story. But the crown and flower of the whole—the inspiration which connected the Round Table and the Graal and the love of Lancelot and Guinevere—though, so far as the present writer's reading and opinion are of any weight, the recent attempts to deprive the Englishman, Walter Map, of the honour of conceiving it are of no force—seems to have waited till the fifteenth century—that is to say the last part of three hundred years—before Englishmen took it up. Most popular of all perhaps, on the principle that in novels the flock "likes the savour of fresh grass," seem to have been the pure romans d'aventures—quite unconnected or nearly so with each other or with any of the larger cycles. Those adventures of particular heroes have sometimes a sort of Arthurian link, but they really have no more to do with the main Arthurian story than if Arthur were not.

For the present purpose, however, filiation, origin, and such-like things are of much less importance than the actual stories that get themselves told to satisfy that demand which in due time is to produce the supply of the novel. Of these the two oldest, as regards the actual forms in which we have them, are capital examples of the more and less original handling of "common-form" stories or motives. They were not then, be it remembered, quite such common-form as now—the rightful heir kept out of his rights, the usurper of them, the princess gracious or scornful or both by turns, the quest, the adventure, the revolutions and discoveries and fights, the wedding bells and the poetical justice on the villain. Let it be remembered, too, if anybody is scornful of these as vieux jeu, that they have never been really improved upon except by the very obvious and unoriginal method common in clever-silly days, of simply reversing some of them, of "turning platitudes topsy-turvy," as not the least gifted, or most old-fashioned, of novelists, Tourguenief, has it. Perhaps the oldest of all, Havelok the Dane—a story the age of which from evidence both internal and external, is so great that people have not quite gratuitously imagined a still older Danish or even Anglo-Saxon original for the French romance from which our existing one is undoubtedly taken—is one of the most spirited of all. Both hero and heroine—Havelok, who should be King of Denmark and Goldborough, who should be Queen of England—are ousted by their treacherous guardian-viceroys as infants; and Havelok is doomed to drowning by his tutor, the greater or at least bolder villain of the two. But the fisherman Grim, who is chosen as his murderer, discovers that the child has, at night, a nimbus of flame round his head; renounces his crime and escapes by sea with the child and his own family to Grimsby. Havelok, growing up undistinguished from his foster-brethren, takes service as a scullion with the English usurper. This usurper is seeking how to rid himself of the princess without violence, but in some way that will make her succession to the crown impossible, and Havelok having shown prowess in sports is selected as the maiden's husband. She, too, discovers his royalty at night by the same token; and the pair regain their respective inheritances and take vengeance on their respective traitors, in a lively and adventurous fashion. There are all the elements of a good story in this: and they are by no means wasted or spoilt in the actual handling. It is not a mere sequence of incident; from the mixture of generosity and canniness in the fisherman who ascertains that he is to have traitor's wages before he finally decides to rescue Havelok, to the not unnatural repugnance of Goldborough at her forced wedding with a scullion, the points where character comes in are not neglected, though of course the author does not avail himself of them either in Shakespearean or in Richardsonian fashion. They are there, ready for development by any person who may take it into his head to develop them.

So too is it in the less powerful and rather more cut and dried King Horn. Here the opening is not so very different; the hero's father is murdered by pirate invaders, and he himself set adrift in a boat. But in this the princess (daughter of course of the king who shelters him) herself falls in love with Horn, and there is even a scene of considerable comic capabilities in which she confides this affection by mistake to one of his companions (fortunately a faithful one) instead of to himself. But Horn has a faithless friend also; and rivals, and adventures, and journeys; and returns just in the nick of time, and recognitions by rings, and everything that can properly be desired occur. In these—even more perhaps than in Havelok's more masculine and less sentimental fortunes—there are openings not entirely neglected by the romancer (though, as has been said, he does not seem to have been one of the strongest of his kind) for digression, expatiation, embroidery. Transpose these two stories (as the slow kind years will teach novelists inevitably to do) into slightly different keys, introduce variations and episodes and codas, and you have the possibilities of a whole library of fiction, as big and as varied as any that has ever established itself for subscribers, and bigger than any that has ever offered itself as one collection to buyers.

The love-stories of these two tales are what it is the fashion—exceedingly complimentary to the age referred to if not to the age of the fashion itself—to call "mid-Victorian" in their complete "propriety." Indeed, it is a Puritan lie, though it seems to possess the vivaciousness of its class, that the romances are distinguished by "bold bawdry." They are on the contrary rather singularly pure, and contrast, in that respect, remarkably with the more popular folk-tale. But fiction, no more than drama, could do without the ἁμαρτἱα—the human and not unpardonable frailty. This appears in, and complicates, the famous story of Tristram, which, though its present English form is probably younger than Havelok and Horn, is likely to have existed earlier: indeed must have done so if Thomas of Erceldoune wrote on the subject. Few can require to be told that beautiful and tragical history of "inauspicious stars" which hardly any man, of the many who have handled it in prose and verse, has been able to spoil. Our Middle English form is not consummate, and is in some places crude in manner and in sentiment. But it is notable that the exaggerated and inartistic repulsiveness of Mark, resorted to by later writers as a rather rudimentary means of exciting compassion for the lovers, is not to be found here; in fact, one of the most poetical touches in the piece is one of sympathy for the luckless husband, when he sees the face of his faithless queen slumbering by her lover's side with the sun on it. "And Mark rewed therefore." The story, especially in its completion with the "Iseult of Brittany" part and the death of Tristram, gives scope for every possible faculty and craftsmanship of the most analytic as of the most picturesque novelist of modern times. There is nothing in the least like it in ancient literature; and to get a single writer who would do it justice in modern times we should have to take the best notes of Charles Kingsley, and Mr. Blackmore, and Mr. Meredith, leaving out all their faults, and combine. It is not surprising that, in the very infancy of the art, nobody in German or French, any more than in English (though the German here is, as it happens, the best), should have done it full justice; but it is a wonder that a story of such capacities should have been sketched, and even worked out in considerable detail, so early.

Of the far greater story of which Tristram is a mere episode and hardly even that—a chantry or out-lying chapel of the great cathedral—the Arthurian Legend, the earlier English versions, or rather the earlier versions in English, are, as has been said, not only fragmentary but disappointing. There is nothing in the least strange in this, even though (as the present writer, who can speak with indifferent knowledge, still firmly holds) the conception of the story itself in its greatest and unifying stage is probably if not certainly English. The original sources of the story of Arthur are no doubt Celtic; they give themselves out as being so, and there is absolutely no critical reason for disbelieving them. But in these earlier forms—the authority of the most learned Celticists who have any literary gift and any appreciation of evidence is decisive on this point—not only are the most characteristic unifying features—the Graal story and the love of Lancelot and Guinevere—completely wanting, but the great stroke of genius—the connection of these two and the subordination of all minor legends as to the dim national hero, Arthur, with those about him—is more conspicuously wanting still. Whether it was the Englishman Walter Map, the Norman Robert de Borron, or the Frenchman Chrestien de Troyes, to whom this flash of illumination came, has never been proved—will pretty certainly now never be proved. M. Gaston Paris failed to do it; and it is exceedingly unlikely that, where he failed, any one else will succeed, unless the thrice and thirty times sifted libraries of Europe yield some quite unexpected windfall. In the works commonly attributed to Chrestien, all of which are well known to the present writer, there is no sign of his having been able to conceive this, though he is a delightful romancer. Robert is a mere shadow; and his attributed works, as his works, are shadows too, though they are interesting enough in themselves. Walter not only has the greatest amount of traditional attribution, but is the undoubted author of De Nugis Curialium. And the author of De Nugis Curialium, different as it is from the Arthurian story, could have finally divined the latter.

But at the time when he wrote, Englishmen, with the rarest exceptions, wrote only in French or Latin; and when they began to write in English, a man of genius, to interpret and improve on him, was not found for a long time. And the most interesting parts of the Arthurian story are rarely handled at all in such early vernacular versions of it as we have, whether in verse or prose. Naturally enough, perhaps, it was the fabulous historic connection with British history, and the story of the great British enchanter Merlin, that attracted most attention. The Arthour and Merlin which is in the Auchinleck MS.; the prose Merlin, published by the Early English Text Society; the alliterative Thornton Morte d'Arthur, and others, are wont to busy themselves about the antecedents of the real story—about the uninteresting wars of the King himself with Saxons, and Romans, and giants, and rival kings, rather than with the great chivalric triple cord of Round Table, Graal, and Guinevere's fault. The pure Graal poems, Joseph of Arimathea, the work of the abominable Lonelich or Lovelich, etc., deal mainly with another branch of previous questions—things bearable as introductions, fillings-up, and so forth, but rather jejune in themselves. The Scots Lancelot is later than Malory himself, and of very little interest. Layamon's account, the oldest that we have, adds little (though what little it does add is not unimportant) to Geoffrey of Monmouth and Wace; and tells what it has to tell with nearly as little skill in narrative as in poetry. Only the metrical Morte—from which, it would appear, Malory actually transprosed some of his most effective passages in the manner in which genius transproses or transverses—has, for that reason, for its dealings with the catastrophe, and for the further opportunity of comparison with Tennyson, interest of the higher kind. But before we come to Malory himself it is desirable to turn to the branches—the chapels, as we have called them, to the cathedral—which he also, in some cases at least, utilised in the magnum opus of English prose romance.
'''

# %% [markdown]
# possible next words for "CAT" are --- is,likes,eats
#
# {
#   "cat" : ["is","likes","eats"],
#   "mat" : ["is"],
#   "the" : ["cat","cat","cat","mat"]
#
# }

# %%
words = text.split()
words
# Out:
# ['the',
#  'cat',
#  'is',
#  'on',
#  'mat.',
#  'the',
#  'cat',
#  'likes',
#  'milk.',
#  'the',
#  'cat',
#  'eats',
#  'milk.',
#  'the',
#  'mat',
#  'is',
#  'on',
#  'the',
#  'floor.',
#  'One',
#  'of',
#  'the',
#  'best',
#  'known,',
#  'and',
#  'one',
#  'of',
#  'the',
#  'least',
#  'intelligible,',
#  'facts',
#  'of',
#  'literary',
#  'history',
#  'is',
#  'the',
#  'lateness,',
#  'in',
#  'Western',
#  'European',
#  'Literature',
#  'at',
#  'any',
#  'rate,',
#  'of',
#  'prose',
#  'fiction,',
#  'and',
#  'the',
#  'comparative',
#  'absence,',
#  'in',
#  'the',
#  'two',
#  'great',
#  'classical',
#  'languages,',
#  'of',
#  'what',
#  'we',
#  'call',
#  'by',
#  'that',
#  'name.',
#  'It',
#  'might',
#  'be',
#  'an',
#  'accident,',
#  'though',
#  'a',
#  'rather',
#  'improbable',
#  'one,',
#  'that',
#  'we',
#  'have',
#  'no',
#  'Greek',
#  'prose',
#  'fiction',
#  'till',
#  'a',
#  'time',
#  'long',
#  'subsequent',
#  'to',
#  'the',
#  'Christian',
#  'era,',
#  'and',
#  'nothing',
#  'in',
#  'Latin',
#  'at',
#  'all',
#  'except',
#  'the',
#  'fragments',
#  'of',
#  'Petronius',
#  'and',
#  'the',
#  'romance',
#  'of',
#  'Apuleius.',
#  'But',
#  'it',
#  'can',
#  'be',
#  'no',
#  'accident,',
#  'and',
#  'it',
#  'is',
#  'a',
#  'very',
#  'momentous',
#  'fact,',
#  'that,',
#  'from',
#  'the',
#  'foundation',
#  'of',
#  'Greek',
#  'criticism,',
#  '"Imitation,"',
#  'that',
#  'is',
#  'to',
#  'say',
#  '"Fiction"',
#  '(for',
#  'it',
#  'is',
#  'neither',
#  'more',
#  'nor',
#  'less),',
#  'was',
#  'regarded',
#  'as',
#  'not',
#  'merely',
#  'the',
#  'inseparable',
#  'but',
#  'the',
#  'constituent',
#  'property',
#  'of',
#  'poetry,',
#  'even',
#  'though',
#  'those',
#  'who',
#  'held',
#  'this',
#  'were',
#  'doubtful',
#  'whether',
#  'poetry',
#  'must',
#  'necessarily',
#  'be',
#  'in',
#  'verse.',
#  'It',
#  'is',
#  'another',
#  'fact',
#  'of',
#  'the',
#  'greatest',
#  'importance',
#  'that',
#  'the',
#  'ancients',
#  'who,',
#  'in',
#  'other',
#  'forms',
#  'than',
#  'deliberate',
#  'prose',
#  'fiction,',
#  'try',
#  'to',
#  '"tell',
#  'a',
#  'story,"',
#  'do',
#  'not',
#  'seem',
#  'to',
#  'know',
#  'very',
#  'well',
#  'how',
#  'to',
#  'do',
#  'it.',
#  'The',
#  'Odyssey',
#  'is,',
#  'indeed,',
#  'one',
#  'of',
#  'the',
#  'greatest',
#  'of',
#  'all',
#  'stories,',
#  'it',
#  'is',
#  'the',
#  'original',
#  'romance',
#  'of',
#  'the',
#  'West;',
#  'but',
#  'the',
#  'Iliad,',
#  'though',
#  'a',
#  'magnificent',
#  'poem,',
#  'is',
#  'not',
#  'much',
#  'of',
#  'a',
#  'story.',
#  'Herodotus',
#  'can',
#  'tell',
#  'one,',
#  'if',
#  'anybody',
#  'can,',
#  'and',
#  'Plato',
#  '(or',
#  'Socrates)',
#  'evidently',
#  'could',
#  'have',
#  'done',
#  'so',
#  'if',
#  'it',
#  'had',
#  'lain',
#  'in',
#  'his',
#  'way:',
#  'while',
#  'the',
#  'Anabasis,',
#  'though',
#  'hardly',
#  'the',
#  'Cyropædia,',
#  'shows',
#  'glimmerings',
#  'in',
#  'Xenophon.',
#  'But',
#  'otherwise',
#  'we',
#  'must',
#  'come',
#  'down',
#  'to',
#  'Lucian',
#  'and',
#  'the',
#  'East',
#  'before',
#  'we',
#  'find',
#  'the',
#  'faculty.',
#  'So,',
#  'too,',
#  'in',
#  'Latin',
#  'before',
#  'the',
#  'two',
#  'late',
#  'writers',
#  'named',
#  'above,',
#  'Ovid',
#  'is',
#  'about',
#  'the',
#  'only',
#  'person',
#  'who',
#  'is',
#  'a',
#  'real',
#  'story-teller.',
#  'Virgil',
#  'makes',
#  'very',
#  'little',
#  'of',
#  'his',
#  'story',
#  'in',
#  'verse:',
#  'and',
#  'it',
#  'is',
#  'shocking',
#  'to',
#  'think',
#  'how',
#  'Livy',
#  'throws',
#  'away',
#  'his',
#  'chances',
#  'in',
#  'prose.',
#  'No:',
#  'putting',
#  'the',
#  'Petronian',
#  'fragments',
#  'aside,',
#  'Lucian',
#  'and',
#  'Apuleius',
#  'are',
#  'the',
#  'only',
#  'two',
#  'novelists',
#  'in',
#  'the',
#  'classical',
#  'languages',
#  'before',
#  'about',
#  '400',
#  'A.D.:',
#  'and',
#  'putting',
#  'aside',
#  'their',
#  'odd',
#  'coincidence',
#  'of',
#  'subject,',
#  'it',
#  'has',
#  'to',
#  'be',
#  'remembered',
#  'that',
#  'Lucian',
#  'was',
#  'a',
#  'Syrian',
#  'Greek',
#  'and',
#  'Apuleius',
#  'an',
#  'African',
#  'Latin.',
#  'The',
#  'conquered',
#  'world',
#  'was',
#  'to',
#  'conquer',
#  'not',
#  'only',
#  'its',
#  'conqueror,',
#  'but',
#  'its',
#  "conqueror's",
#  'teacher,',
#  'in',
#  'this',
#  'youngest',
#  'accomplishment',
#  'of',
#  'literary',
#  'art.',
#  'It',
#  'was',
#  'probably',
#  'in',
#  'all',
#  'cases,',
#  'if',
#  'not',
#  'certainly,',
#  'mixed',
#  'blood',
#  'that',
#  'produced',
#  'the',
#  'curious',
#  'development',
#  'generally',
#  'called',
#  'Greek',
#  'Romance.',
#  'It',
#  'is',
#  'no',
#  'part',
#  'of',
#  'our',
#  'business',
#  'to',
#  'survey,',
#  'in',
#  'any',
#  'detail,',
#  'the',
#  'not',
#  'very',
#  'numerous',
#  'but',
#  'distinctly',
#  'interesting',
#  'compositions',
#  'which',
#  'range',
#  'in',
#  'point',
#  'of',
#  'authorship',
#  'from',
#  'Longus',
#  'and',
#  'Heliodorus,',
#  'probably',
#  'at',
#  'the',
#  'meeting',
#  'of',
#  'the',
#  'fourth',
#  'and',
#  'fifth',
#  'centuries,',
#  'to',
#  'Eustathius',
#  'in',
#  'the',
#  'twelfth.',
#  'At',
#  'one',
#  'time',
#  'indeed,',
#  'when',
#  'we',
#  'may',
#  'return',
#  'to',
#  'them',
#  'a',
#  'little,',
#  'we',
#  'shall',
#  'find',
#  'them',
#  'exercising',
#  'direct',
#  'and',
#  'powerful',
#  'influence',
#  'on',
#  'modern',
#  'European',
#  'fiction,',
#  'and',
#  'so',
#  'both',
#  'directly',
#  'and',
#  'indirectly',
#  'on',
#  'English:',
#  'but',
#  'that',
#  'is',
#  'a',
#  'time',
#  'a',
#  'good',
#  'way',
#  'removed',
#  'from',
#  'the',
#  'actual',
#  'beginning',
#  'of',
#  'our',
#  'journey.',
#  'Still,',
#  'Apollonius',
#  'of',
#  'Tyre,',
#  'which',
#  'is',
#  'probably',
#  'the',
#  'oldest',
#  'piece',
#  'of',
#  'English',
#  'prose',
#  'fiction',
#  'that',
#  'we',
#  'have,',
#  'is',
#  'beyond',
#  'all',
#  'doubt',
#  'derived',
#  'ultimately',
#  'from',
#  'a',
#  'Greek',
#  'original',
#  'of',
#  'this',
#  'very',
#  'class:',
#  'and',
#  'the',
#  'class',
#  'itself',
#  'is',
#  'an',
#  'immense',
#  'advance,',
#  'in',
#  'the',
#  'novel',
#  'direction,',
#  'upon',
#  'anything',
#  'that',
#  'we',
#  'have',
#  'before.',
#  'It',
#  'is',
#  'on',
#  'the',
#  'one',
#  'hand',
#  'essentially',
#  'a',
#  '"romance',
#  'of',
#  'adventure,"',
#  'and',
#  'on',
#  'the',
#  'other',
#  'essentially',
#  'a',
#  '"love-story"—in',
#  'senses',
#  'to',
#  'which',
#  'we',
#  'find',
#  'little',
#  'in',
#  'classical',
#  'literature',
#  'to',
#  'correspond',
#  'in',
#  'the',
#  'one',
#  'case',
#  'and',
#  'still',
#  'less',
#  'in',
#  'the',
#  'other.',
#  'Instead',
#  'of',
#  'being,',
#  'like',
#  'Lucius',
#  'and',
#  'the',
#  'Golden',
#  'Ass,',
#  'a',
#  'tissue',
#  'of',
#  'stories',
#  'essentially',
#  'unconnected',
#  'and',
#  'little',
#  'more',
#  'than',
#  'framed',
#  'by',
#  'the',
#  'main',
#  'tale,',
#  'it',
#  'is,',
#  'though',
#  'it',
#  'may',
#  'have',
#  'a',
#  'few',
#  'episodes,',
#  'an',
#  'example',
#  'of',
#  'at',
#  'least',
#  'romantic',
#  'unity',
#  'throughout,',
#  'with',
#  'definite',
#  'hero',
#  'and',
#  'definite',
#  'heroine,',
#  'the',
#  'prominence',
#  'and',
#  'importance',
#  'of',
#  'the',
#  'latter',
#  'being',
#  'specially',
#  'noteworthy.',
#  'It',
#  'is',
#  'in',
#  'fact',
#  'the',
#  'first',
#  'division',
#  'of',
#  'literature',
#  'in',
#  'which',
#  'the',
#  'heroine',
#  'assumes',
#  'the',
#  'position',
#  'of',
#  'a',
#  'protagonist.',
#  'If',
#  'it',
#  'falls',
#  'short',
#  'in',
#  'character,',
#  'so',
#  'do',
#  'even',
#  'later',
#  'romances',
#  'to',
#  'a',
#  'great',
#  'extent:',
#  'if',
#  'dialogue',
#  'is',
#  'not',
#  'very',
#  'accomplished,',
#  'that',
#  'also',
#  'was',
#  'hardly',
#  'to',
#  'be',
#  'thoroughly',
#  'developed',
#  'till',
#  'the',
#  'novel',
#  'proper',
#  'came',
#  'into',
#  'being.',
#  'In',
#  'the',
#  'other',
#  'two',
#  'great',
#  'divisions,',
#  'incident',
#  'and',
#  'description,',
#  'it',
#  'is',
#  'abundantly',
#  'furnished.',
#  'And,',
#  'above',
#  'all,',
#  'the',
#  'two',
#  'great',
#  'Romantic',
#  'motives,',
#  'Adventure',
#  'and',
#  'Love,',
#  'are',
#  'quite',
#  'maturely',
#  'present',
#  'in',
#  'it.',
#  'To',
#  'pass',
#  'to',
#  'the',
#  'deluge,',
#  'and',
#  'beyond',
#  'it,',
#  'and',
#  'to',
#  'come',
#  'to',
#  'close',
#  'quarters',
#  'with',
#  'our',
#  'proper',
#  'division,',
#  'the',
#  'origin',
#  'of',
#  'Romance',
#  'itself',
#  'is',
#  'a',
#  'very',
#  'debatable',
#  'subject,',
#  'or',
#  'rather',
#  'it',
#  'is',
#  'a',
#  'subject',
#  'which',
#  'the',
#  'wiser',
#  'mind',
#  'will',
#  'hardly',
#  'care',
#  'to',
#  'debate',
#  'much.',
#  'The',
#  'opinion',
#  'of',
#  'the',
#  'present',
#  'writer—the',
#  'result,',
#  'at',
#  'least,',
#  'of',
#  'many',
#  "years'",
#  'reading',
#  'and',
#  'thought—is',
#  'that',
#  'it',
#  'is',
#  'a',
#  'result',
#  'of',
#  'the',
#  'marriage',
#  'of',
#  'the',
#  'older',
#  'East',
#  'and',
#  'the',
#  'newer',
#  '(non-classical)',
#  'West',
#  'through',
#  'the',
#  'agency',
#  'of',
#  'the',
#  'spread',
#  'of',
#  'Christianity',
#  'and',
#  'the',
#  'growth',
#  'and',
#  'diffusion',
#  'of',
#  'the',
#  '"Saint\'s',
#  'Life."',
#  'The',
#  'beginnings',
#  'of',
#  'Hagiology',
#  'itself',
#  'are',
#  'very',
#  'uncertain:',
#  'but',
#  'what',
#  'is',
#  'certain',
#  'is',
#  'that',
#  'they',
#  'are',
#  'very',
#  'early:',
#  'and',
#  'that',
#  'as',
#  'the',
#  'amalgamation',
#  'or',
#  'leavening',
#  'of',
#  'the',
#  'Roman',
#  'world',
#  'with',
#  'barbarian',
#  'material',
#  'proceeded,',
#  'the',
#  'spread',
#  'of',
#  'Christianity',
#  'proceeded',
#  'likewise.',
#  'The',
#  'Vision',
#  'of',
#  'St.',
#  'Paul—one',
#  'of',
#  'the',
#  'earliest',
#  'examples',
#  'and',
#  'the',
#  'starter',
#  'it',
#  'would',
#  'seem,',
#  'if',
#  'not',
#  'of',
#  'the',
#  'whole',
#  'class',
#  'of',
#  'sacred',
#  'Romances,',
#  'at',
#  'any',
#  'rate',
#  'of',
#  'the',
#  'large',
#  'subsection',
#  'devoted',
#  'to',
#  'Things',
#  'after',
#  'Death—has',
#  'been',
#  'put',
#  'as',
#  'early',
#  'as',
#  '"before',
#  '400',
#  'A.D."',
#  'It',
#  'would',
#  'probably',
#  'be',
#  'difficult',
#  'to',
#  'date',
#  'such',
#  'legends',
#  'as',
#  'those',
#  'of',
#  'St.',
#  'Margaret',
#  'and',
#  'St.',
#  'Catherine',
#  'too',
#  'early,',
#  'having',
#  'regard',
#  'to',
#  'their',
#  'intrinsic',
#  'indications:',
#  'and',
#  'the',
#  'vast',
#  'cycle',
#  'of',
#  'Our',
#  'Lady,',
#  'though',
#  'probably',
#  'later,',
#  'must',
#  'have',
#  'begun',
#  'long',
#  'before',
#  'the',
#  'modern',
#  'languages',
#  'were',
#  'ready',
#  'for',
#  'it,',
#  'while',
#  'that',
#  'of',
#  'the',
#  'Cross',
#  'should',
#  'be',
#  'earlier',
#  'still.',
#  'And',
#  'let',
#  'it',
#  'be',
#  'remembered',
#  'that',
#  'these',
#  "Saints'",
#  'Lives,',
#  'which',
#  'are',
#  'still',
#  'infinitely',
#  'good',
#  'reading,',
#  'are',
#  'not',
#  'in',
#  'the',
#  'least',
#  'confined',
#  'to',
#  'homiletic',
#  'necessities.',
#  'The',
#  'jejuneness',
#  'and',
#  'woodenness',
#  ...]

# %%
len(words)
# Out:
# 5109

# %%
# word dictionary

word_dict = {}
# {"the" : ["cat","cat"],
#  "cat" : ["is","likes"]
#  "is" : ["on"],
#  "on" : ["mat"],
#  "mat" : ["is"],
#  "likes" : ["milk"],
#  "eats" : ["milk"],
#  "milk
#  }


for i in range(len(words)-1):
  word = words[i]
  next_word = words[i+1]
  # print(word,next_word)

  if word not in word_dict:
    word_dict[word] = [next_word]
  else:
    word_dict[word].append(next_word)

word_dict
# Out:
# {'the': ['cat',
#   'cat',
#   'cat',
#   'mat',
#   'floor.',
#   'best',
#   'least',
#   'lateness,',
#   'comparative',
#   'two',
#   'Christian',
#   'fragments',
#   'romance',
#   'foundation',
#   'inseparable',
#   'constituent',
#   'greatest',
#   'ancients',
#   'greatest',
#   'original',
#   'West;',
#   'Iliad,',
#   'Anabasis,',
#   'Cyropædia,',
#   'East',
#   'faculty.',
#   'two',
#   'only',
#   'Petronian',
#   'only',
#   'classical',
#   'curious',
#   'not',
#   'meeting',
#   'fourth',
#   'twelfth.',
#   'actual',
#   'oldest',
#   'class',
#   'novel',
#   'one',
#   'other',
#   'one',
#   'other.',
#   'Golden',
#   'main',
#   'prominence',
#   'latter',
#   'first',
#   'heroine',
#   'position',
#   'novel',
#   'other',
#   'two',
#   'deluge,',
#   'origin',
#   'wiser',
#   'present',
#   'marriage',
#   'older',
#   'newer',
#   'agency',
#   'spread',
#   'growth',
#   '"Saint\'s',
#   'amalgamation',
#   'Roman',
#   'spread',
#   'earliest',
#   'starter',
#   'whole',
#   'large',
#   'vast',
#   'modern',
#   'Cross',
#   'least',
#   'modern',
#   'widest',
#   'parallel',
#   'dramatising',
#   'sweep,',
#   'pace',
#   'literature',
#   'department',
#   'main',
#   'almost',
#   'version',
#   'famous',
#   'most',
#   'Shakespearean',
#   'Latin',
#   'subject.',
#   'daughter',
#   'narrative',
#   'prose',
#   'tale',
#   'monk',
#   'Caedmon',
#   'vision',
#   'other',
#   'verse',
#   'first',
#   'primest',
#   'Odyssey',
#   'adventures',
#   'Golden',
#   'story-work',
#   'other',
#   'slightest',
#   'first',
#   'story',
#   'effect',
#   '"Finnsburgh"',
#   "Saints'",
#   'Andreas,',
#   'slender',
#   'Guthlac',
#   'Juliana.',
#   'very',
#   'classics,',
#   'case',
#   'future',
#   'department',
#   'adventures',
#   'smith',
#   'historian',
#   'Smith,',
#   'tale',
#   'main',
#   'great',
#   'ancients',
#   'earlier',
#   'whole',
#   'historian',
#   'novel',
#   'right',
#   'counter-arguments',
#   'first',
#   'idea',
#   'novel',
#   'second',
#   'exclusive',
#   'novel',
#   'road',
#   'last',
#   'help',
#   'ants',
#   'matter,',
#   'story',
#   'story',
#   'elect:',
#   'narrative',
#   'dramatic)',
#   'novel',
#   'Kreutzer',
#   'triumphs',
#   '"Imitation"—the',
#   'dramatic',
#   'poetical',
#   'dramatic',
#   'poetical',
#   'result',
#   'germ',
#   'suggestion',
#   'name.',
#   'Tristram',
#   'Lancelot',
#   'things',
#   'romancer',
#   'novelist',
#   'end',
#   'world;',
#   'possibilities',
#   'latter',
#   'beginning',
#   'vehicle',
#   'minor',
#   'dress',
#   'scene-backing',
#   'mouth',
#   'not',
#   'actual',
#   'Middle',
#   'treasures',
#   'matter',
#   'same',
#   'invaluable',
#   'collections',
#   'last',
#   'publications',
#   'Early',
#   'reach',
#   'minimum',
#   'stories',
#   'stock',
#   'French',
#   'imitation',
#   'class',
#   'most',
#   'Saracens',
#   'universally',
#   'almost',
#   'more',
#   '"matter',
#   'foreign',
#   'still',
#   'other',
#   'Graal',
#   'crown',
#   'whole—the',
#   'Round',
#   'Graal',
#   'love',
#   'present',
#   'recent',
#   'Englishman,',
#   'honour',
#   'fifteenth',
#   'last',
#   'principle',
#   'flock',
#   'savour',
#   'pure',
#   'larger',
#   'main',
#   'present',
#   'actual',
#   'supply',
#   'novel.',
#   'two',
#   'actual',
#   'more',
#   'usurper',
#   'princess',
#   'quest,',
#   'adventure,',
#   'revolutions',
#   'wedding',
#   'poetical',
#   'villain.',
#   'very',
#   'least',
#   'oldest',
#   'Dane—a',
#   'age',
#   'French',
#   'most',
#   'greater',
#   'two.',
#   'fisherman',
#   'child',
#   'child',
#   'English',
#   'princess',
#   'crown',
#   "maiden's",
#   'same',
#   'pair',
#   'elements',
#   'actual',
#   'mixture',
#   'fisherman',
#   'not',
#   'points',
#   'author',
#   'less',
#   'opening',
#   "hero's",
#   'princess',
#   'king',
#   'nick',
#   'romancer',
#   'strongest',
#   'slow',
#   'possibilities',
#   'fashion—exceedingly',
#   'age',
#   'age',
#   'fashion',
#   'vivaciousness',
#   'romances',
#   'contrary',
#   'more',
#   'ἁμαρτἱα—the',
#   'famous',
#   'subject.',
#   'many',
#   'exaggerated',
#   'lovers,',
#   'most',
#   'piece',
#   'luckless',
#   'face',
#   'sun',
#   '"Iseult',
#   'death',
#   'most',
#   'most',
#   'least',
#   'best',
#   'very',
#   'art,',
#   'German',
#   'best),',
#   'far',
#   'great',
#   'earlier',
#   'earlier',
#   'least',
#   'present',
#   'conception',
#   'story',
#   'story',
#   'most',
#   'most',
#   'love',
#   'great',
#   'subordination',
#   'dim',
#   'Englishman',
#   'Norman',
#   'Frenchman',
#   'thrice',
#   'works',
#   'present',
#   'greatest',
#   'undoubted',
#   'author',
#   'Arthurian',
#   'latter.',
#   'time',
#   'rarest',
#   'most',
#   'Arthurian',
#   'fabulous',
#   'story',
#   'great',
#   'Auchinleck',
#   'prose',
#   'Early',
#   'alliterative',
#   'antecedents',
#   'real',
#   'uninteresting',
#   'King',
#   'great',
#   'work',
#   'abominable',
#   'oldest',
#   'metrical',
#   'manner',
#   'catastrophe,',
#   'further',
#   'higher',
#   'branches—the',
#   'cathedral—which',
#   'magnum'],
#  'cat': ['is', 'likes', 'eats'],
#  'is': ['on',
#   'on',
#   'the',
#   'a',
#   'to',
#   'neither',
#   'another',
#   'the',
#   'not',
#   'about',
#   'a',
#   'shocking',
#   'no',
#   'a',
#   'probably',
#   'beyond',
#   'an',
#   'on',
#   'in',
#   'not',
#   'abundantly',
#   'a',
#   'a',
#   'a',
#   'certain',
#   'that',
#   'very',
#   'something',
#   'different',
#   'not',
#   'in',
#   'observable',
#   'a',
#   'fool',
#   'character—not',
#   'by',
#   'some',
#   'far',
#   'a',
#   'now',
#   'that',
#   'really',
#   'unnatural',
#   'a',
#   'really',
#   'a',
#   'a',
#   'the',
#   'at',
#   'a',
#   'sufficient',
#   'little',
#   'some',
#   'nearly',
#   'not',
#   'probable',
#   'certain:',
#   'obvious.',
#   'not',
#   'perhaps',
#   'that',
#   'to',
#   'to',
#   'scornful',
#   'so',
#   'undoubtedly',
#   'doomed',
#   'chosen',
#   'seeking',
#   'selected',
#   'not',
#   'to',
#   'it',
#   'not',
#   'murdered',
#   'even',
#   'the',
#   'a',
#   'probably',
#   'likely',
#   'not',
#   'in',
#   'notable',
#   'not',
#   'one',
#   'nothing',
#   'not',
#   'a',
#   'a',
#   'nothing',
#   'probably',
#   'absolutely',
#   'decisive',
#   'exceedingly',
#   'no',
#   'a',
#   'a',
#   'the',
#   'from',
#   'in',
#   'later',
#   'not',
#   'desirable'],
#  'on': ['mat.',
#   'the',
#   'modern',
#   'English:',
#   'the',
#   'the',
#   'St.',
#   'the',
#   'the',
#   'few',
#   'many.',
#   'its',
#   'a',
#   'this',
#   'the',
#   'the',
#   'their',
#   'the',
#   'the',
#   'it.',
#   'this',
#   'him,'],
#  'mat.': ['the'],
#  'likes': ['milk.'],
#  'milk.': ['the', 'the'],
#  'eats': ['milk.'],
#  'mat': ['is'],
#  'floor.': ['One'],
#  'One': ['of', 'may'],
#  'of': ['the',
#   'the',
#   'literary',
#   'prose',
#   'what',
#   'Petronius',
#   'Apuleius.',
#   'Greek',
#   'poetry,',
#   'the',
#   'the',
#   'all',
#   'the',
#   'a',
#   'his',
#   'subject,',
#   'literary',
#   'our',
#   'authorship',
#   'the',
#   'our',
#   'Tyre,',
#   'English',
#   'this',
#   'adventure,"',
#   'being,',
#   'stories',
#   'at',
#   'the',
#   'literature',
#   'a',
#   'Romance',
#   'the',
#   'many',
#   'the',
#   'the',
#   'the',
#   'Christianity',
#   'the',
#   'Hagiology',
#   'the',
#   'Christianity',
#   'St.',
#   'the',
#   'the',
#   'sacred',
#   'the',
#   'St.',
#   'Our',
#   'the',
#   'them.',
#   'incident—natural',
#   'nature',
#   'these',
#   'them,',
#   'English',
#   'fiction',
#   'English',
#   'Anglo-Saxon',
#   'it—the',
#   'its',
#   'the',
#   'Apollonius',
#   'Tyre,',
#   'the',
#   'narrative',
#   'the',
#   'Arcestrates,',
#   'telling',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'exhibiting',
#   'our',
#   'one',
#   'the',
#   'the',
#   'two',
#   '"conveyance"',
#   'the',
#   'adventure—and',
#   'Waldhere',
#   'all',
#   '"happenings")',
#   'Anglo-Saxon',
#   'approximation',
#   'some',
#   'English',
#   'fiction.',
#   'background',
#   'Pompeii:',
#   'Deor,',
#   'the',
#   'a',
#   'fantastic',
#   'actual',
#   'Fiction',
#   'the',
#   'kinds;',
#   'all',
#   'Romance',
#   'it,',
#   'the',
#   'his',
#   'entry',
#   'them',
#   'the',
#   'the',
#   'partition',
#   'Novel',
#   'the',
#   'the',
#   'romance',
#   'incident',
#   'character',
#   'the',
#   'a',
#   'fact,',
#   'your',
#   'Mr.',
#   'a',
#   'romance',
#   'the',
#   'incident',
#   'character',
#   'the',
#   'the',
#   'situation,',
#   'one',
#   'an',
#   'varying',
#   'mere',
#   'English',
#   'English',
#   'them.',
#   'the',
#   '[British',
#   'Ritson',
#   'the',
#   'everybody',
#   'obsolete',
#   'intelligent',
#   'importance)',
#   'print',
#   'the',
#   'mediæval',
#   'the',
#   'all',
#   'French',
#   'antiquity—though',
#   'the',
#   'Troy;',
#   'them.',
#   'the',
#   'Britain"',
#   'Arthur',
#   'Tristram',
#   'the',
#   'adventures',
#   'course',
#   'the',
#   'the',
#   'Lancelot',
#   'any',
#   'the',
#   'conceiving',
#   'no',
#   'three',
#   'all',
#   'fresh',
#   'the',
#   'particular',
#   'Arthurian',
#   'much',
#   'the',
#   'the',
#   '"common-form"',
#   'his',
#   'them,',
#   'these',
#   'simply',
#   'them,',
#   '"turning',
#   'novelists,',
#   'all,',
#   'which',
#   'the',
#   'all.',
#   'Denmark',
#   'England—are',
#   'the',
#   'flame',
#   'the',
#   'a',
#   'incident;',
#   'generosity',
#   'Goldborough',
#   'course',
#   'them',
#   'course',
#   'the',
#   'considerable',
#   'his',
#   'to',
#   'time,',
#   'the',
#   'his',
#   'a',
#   'fiction,',
#   'these',
#   'the',
#   'its',
#   'Tristram,',
#   'Erceldoune',
#   '"inauspicious',
#   'the',
#   'Mark,',
#   'exciting',
#   'the',
#   'sympathy',
#   'his',
#   'Brittany"',
#   'Tristram,',
#   'the',
#   'the',
#   'modern',
#   'Charles',
#   'the',
#   'such',
#   'which',
#   'the',
#   'the',
#   'the',
#   'Arthur',
#   'the',
#   'evidence',
#   'Lancelot',
#   'genius—the',
#   'these',
#   'all',
#   'illumination',
#   'Europe',
#   'which',
#   'his',
#   'traditional',
#   'De',
#   'De',
#   'genius,',
#   'the',
#   'it',
#   'the',
#   'the',
#   'the',
#   'Round',
#   'Arimathea,',
#   'the',
#   'previous',
#   'very',
#   'Monmouth',
#   'his',
#   'comparison',
#   'the',
#   'English'],
#  'best': ['known,', 'notes'],
#  'known,': ['and'],
#  'and': ['one',
#   'the',
#   'nothing',
#   'the',
#   'it',
#   'Plato',
#   'the',
#   'it',
#   'Apuleius',
#   'putting',
#   'Apuleius',
#   'Heliodorus,',
#   'fifth',
#   'powerful',
#   'so',
#   'indirectly',
#   'the',
#   'on',
#   'still',
#   'the',
#   'little',
#   'definite',
#   'importance',
#   'description,',
#   'Love,',
#   'beyond',
#   'to',
#   'thought—is',
#   'the',
#   'the',
#   'diffusion',
#   'that',
#   'the',
#   'St.',
#   'the',
#   'woodenness',
#   'these,',
#   'to',
#   'quicken',
#   'then,',
#   'last',
#   'the',
#   'prose',
#   'contemporary',
#   'to',
#   'it',
#   'in',
#   'his',
#   'with',
#   'Homilies,',
#   'of',
#   'one',
#   'he',
#   'graces)',
#   'there',
#   'picturesque',
#   'the',
#   'the',
#   'which',
#   'certainly',
#   'The',
#   'others,',
#   'decadent',
#   'a',
#   'circumstances',
#   'contrast',
#   'character.',
#   'poetry',
#   'least',
#   'position',
#   'novel',
#   'that',
#   'Richardson,',
#   'sometimes',
#   'any',
#   'unhistorical:',
#   'write',
#   'Romance',
#   'deeper,',
#   'novel—of',
#   'the',
#   'motive—is',
#   'psychologically.',
#   'it',
#   'it',
#   'master',
#   'have',
#   'Chloe,',
#   'the',
#   'more;',
#   'possibility',
#   'the',
#   'the',
#   'motive',
#   'Malory',
#   'greater',
#   'tales',
#   'the',
#   'scene-backing.',
#   'families,',
#   'so',
#   'places—to',
#   'still',
#   'survey',
#   'much',
#   'delightful',
#   'Weber,',
#   'enlarged',
#   'a',
#   'variety',
#   'the',
#   'Vortigern',
#   'Percivale,',
#   'not',
#   'other',
#   'flower',
#   'the',
#   'the',
#   'Guinevere—though,',
#   'opinion',
#   'such-like',
#   'less',
#   'discoveries',
#   'fights,',
#   'the',
#   'unoriginal',
#   'external,',
#   'heroine—Havelok,',
#   'Goldborough,',
#   'Havelok',
#   'escapes',
#   'his',
#   'Havelok',
#   'the',
#   'take',
#   'adventurous',
#   'they',
#   'canniness',
#   'rather',
#   'dried',
#   'he',
#   'there',
#   'rivals,',
#   'adventures,',
#   'journeys;',
#   'returns',
#   'recognitions',
#   'everything',
#   'less',
#   'episodes',
#   'codas,',
#   'you',
#   'as',
#   'bigger',
#   'contrast,',
#   'not',
#   'complicates,',
#   'Horn,',
#   'tragical',
#   'verse,',
#   'is',
#   'in',
#   'inartistic',
#   'the',
#   'craftsmanship',
#   'to',
#   'Mr.',
#   'Mr.',
#   'combine.',
#   'even',
#   'hardly',
#   'unifying',
#   'there',
#   'any',
#   'the',
#   'Guinevere—completely',
#   'the',
#   'it',
#   'thirty',
#   'his',
#   'when',
#   'improve',
#   'the',
#   'Merlin',
#   'others,',
#   'Romans,',
#   'giants,',
#   'rival',
#   "Guinevere's",
#   'so',
#   'of',
#   'Wace;',
#   'tells',
#   'for'],
#  'one': ['of',
#   'of',
#   'time',
#   'hand',
#   'case',
#   'first-rate',
#   'second-rate',
#   'sorry',
#   'more',
#   'may',
#   'of',
#   'practical',
#   'who',
#   'particular',
#   'who',
#   'of',
#   'is',
#   'of',
#   'of',
#   'of',
#   'collection',
#   'of',
#   'of',
#   'else'],
#  'least': ['intelligible,',
#   'romantic',
#   'confined',
#   'in',
#   'of',
#   'taken',
#   'the',
#   'gifted,',
#   'bolder',
#   'like',
#   'strange'],
#  'intelligible,': ['facts'],
#  'facts': ['of'],
#  'literary': ['history', 'art.', 'history,', 'gift'],
#  'history': ['is', 'of'],
#  'lateness,': ['in'],
#  'in': ['Western',
#   'the',
#   'Latin',
#   'verse.',
#   'other',
#   'his',
#   'Xenophon.',
#   'Latin',
#   'verse:',
#   'prose.',
#   'the',
#   'this',
#   'all',
#   'any',
#   'point',
#   'the',
#   'the',
#   'classical',
#   'the',
#   'the',
#   'fact',
#   'which',
#   'character,',
#   'it.',
#   'the',
#   'no',
#   'the',
#   'the',
#   'prose.',
#   'Anglo-Saxon,',
#   'the',
#   'passages',
#   'company—that',
#   'the',
#   'fact',
#   'these',
#   'Latin',
#   "Bede's",
#   'the',
#   'such',
#   'the',
#   'the',
#   'the',
#   'the',
#   'the',
#   'them,',
#   'the',
#   'all',
#   'its',
#   'life',
#   'the',
#   'our',
#   'English),',
#   'part,',
#   'whole,',
#   'literature.',
#   'it,',
#   'literary',
#   'appearance',
#   'the',
#   'posse,',
#   'esse,',
#   'the',
#   'the',
#   'every',
#   'the',
#   'verse',
#   'the',
#   'fiction—mostly',
#   'the',
#   'them',
#   'France—the',
#   'English.',
#   'several',
#   'handling',
#   'novels',
#   'due',
#   'which',
#   'clever-silly',
#   'some',
#   'sports',
#   'a',
#   'this:',
#   'the',
#   'the',
#   'are',
#   'Shakespearean',
#   'Richardsonian',
#   'the',
#   'a',
#   'this',
#   'love',
#   'which',
#   'the',
#   "Havelok's",
#   'their',
#   'that',
#   'prose',
#   'some',
#   'manner',
#   'sentiment.',
#   'fact,',
#   'the',
#   'its',
#   'the',
#   'ancient',
#   'modern',
#   'the',
#   'German',
#   'English',
#   'considerable',
#   'English,',
#   'the',
#   'this,',
#   'its',
#   'these',
#   'themselves.',
#   'French',
#   'English,',
#   'such',
#   'verse',
#   'the',
#   'themselves.',
#   'narrative',
#   'poetry.',
#   'the',
#   'which',
#   'some',
#   'the'],
#  'Western': ['European'],
#  'European': ['Literature', 'fiction,'],
#  'Literature': ['at'],
#  'at': ['any',
#   'all',
#   'the',
#   'least',
#   'least,',
#   'any',
#   'earliest',
#   'least',
#   'least',
#   'all',
#   'all.',
#   'least',
#   'night,',
#   'night',
#   'her',
#   'the',
#   'all',
#   'least,'],
#  'any': ['rate,',
#   'detail,',
#   'rate',
#   'large',
#   'one',
#   'other',
#   'weight,',
#   'of',
#   'person',
#   'that',
#   'that',
#   'man,',
#   'more',
#   'literary',
#   'appreciation',
#   'one'],
#  'rate,': ['of'],
#  'prose': ['fiction,',
#   'fiction',
#   'fiction,',
#   'fiction',
#   'departments.',
#   "Saints'",
#   'and',
#   'or',
#   'was',
#   'and',
#   'Merlin,',
#   'romance.'],
#  'fiction,': ['and', 'try', 'and', 'as', 'no'],
#  'comparative': ['absence,'],
#  'absence,': ['in'],
#  'two': ['great',
#   'late',
#   'novelists',
#   'great',
#   'great',
#   'mightiest',
#   'centuries.',
#   'or',
#   'oldest,',
#   'stories',
#   'tales',
#   'and'],
#  'great': ['classical',
#   'extent:',
#   'divisions,',
#   'Romantic',
#   'requirements',
#   'that',
#   'cathedral—the',
#   'stroke',
#   'British',
#   'chivalric'],
#  'classical': ['languages,', 'languages', 'literature'],
#  'languages,': ['of'],
#  'what': ['we', 'is', 'might', 'has', 'it', 'little', 'it'],
#  'we': ['call',
#   'have',
#   'must',
#   'find',
#   'may',
#   'shall',
#   'have,',
#   'have',
#   'find',
#   'must',
#   'possess;',
#   'must',
#   'are',
#   'have',
#   'have',
#   'have',
#   'have',
#   'should',
#   'have,',
#   'have,',
#   'come',
#   'have'],
#  'call': ['by', 'him)', '"mid-Victorian"'],
#  'by': ['that',
#   'the',
#   'no',
#   'Chaucer,',
#   'his',
#   'no',
#   'a',
#   'itself.',
#   'Dunlop',
#   'the',
#   'Mr.',
#   'others,',
#   'the',
#   'a',
#   'turns,',
#   'the',
#   'their',
#   'his',
#   'sea',
#   'the',
#   'no',
#   'any',
#   'pirate',
#   'mistake',
#   'rings,',
#   'the',
#   '"bold',
#   'later',
#   'her',
#   'the'],
#  'that': ['name.',
#   'we',
#   'is',
#   'the',
#   'Lucian',
#   'produced',
#   'is',
#   'we',
#   'we',
#   'also',
#   'it',
#   'they',
#   'as',
#   'of',
#   'these',
#   'of',
#   'might',
#   'some',
#   'is',
#   'one',
#   'romance',
#   'the',
#   'succoured',
#   'heap',
#   'Count',
#   'deserves',
#   'the',
#   'no',
#   'they',
#   'it',
#   'few',
#   'most',
#   'until',
#   'in',
#   'get',
#   'demand',
#   'they',
#   'people',
#   'the',
#   'will',
#   'he',
#   'can',
#   'has',
#   'has',
#   'the',
#   'respect,',
#   'beautiful',
#   'the',
#   'a',
#   'attracted',
#   'we',
#   'reason,'],
#  'name.': ['It', 'In'],
#  'It': ['might',
#   'is',
#   'was',
#   'is',
#   'is',
#   'is',
#   'would',
#   'most',
#   'is',
#   'made',
#   'has',
#   'is',
#   'is',
#   'is',
#   'is'],
#  'might': ['be', 'have', 'have'],
#  'be': ['an',
#   'no',
#   'in',
#   'remembered',
#   'thoroughly',
#   'difficult',
#   'earlier',
#   'remembered',
#   'afterwards',
#   'enshrined',
#   'overpraised:',
#   'ill',
#   'followed',
#   'disgusted',
#   'it',
#   'remembered,',
#   'King',
#   'Queen',
#   'desired',
#   'told',
#   'found',
#   'proved.'],
#  'an': ['accident,',
#   'African',
#   'immense',
#   'example',
#   'early',
#   'example',
#   'age'],
#  'accident,': ['though', 'and'],
#  'though': ['a',
#   'those',
#   'a',
#   'hardly',
#   'it',
#   'probably',
#   'there',
#   'agreeable',
#   'he',
#   'few',
#   'on',
#   'no',
#   'we',
#   'of',
#   'it',
#   'its',
#   '(as',
#   'he',
#   'they'],
#  'a': ['rather',
#   'time',
#   'very',
#   'story,"',
#   'magnificent',
#   'story.',
#   'real',
#   'Syrian',
#   'little,',
#   'time',
#   'good',
#   'Greek',
#   '"romance',
#   '"love-story"—in',
#   'tissue',
#   'few',
#   'protagonist.',
#   'great',
#   'very',
#   'subject',
#   'result',
#   'secular',
#   'third',
#   'translation',
#   'story',
#   '"yarn"',
#   'tolerably',
#   'mere',
#   'kind:',
#   'sort',
#   'few',
#   'sort',
#   'later',
#   'certain',
#   'good',
#   'doctrine',
#   'pedantic',
#   'third',
#   'mistake',
#   'very',
#   'mistake',
#   'greater',
#   'more',
#   'matter',
#   'novel',
#   'whole',
#   'hectograph,',
#   'result',
#   'contribution',
#   'very',
#   'rather',
#   'very',
#   'single',
#   'few',
#   'very',
#   'few',
#   'little,',
#   'sort',
#   'still',
#   'nimbus',
#   'scullion',
#   'lively',
#   'good',
#   'mere',
#   'scullion,',
#   'boat.',
#   'scene',
#   'faithful',
#   'faithless',
#   'whole',
#   'Puritan',
#   'rather',
#   'single',
#   'wonder',
#   'story',
#   'mere',
#   'delightful',
#   'mere',
#   'man',
#   'long'],
#  'rather': ['improbable',
#   'it',
#   'prosaic,',
#   'large',
#   'more',
#   'singularly',
#   'rudimentary',
#   'the',
#   'than',
#   'jejune'],
#  'improbable': ['one,'],
#  'one,': ['that', 'if', 'even'],
#  'have': ['no',
#   'done',
#   'before.',
#   'a',
#   'begun',
#   'the',
#   'combined',
#   'been',
#   'only',
#   'better',
#   'been',
#   'been',
#   'seen',
#   'excogitated',
#   'set',
#   'made',
#   'started',
#   'the',
#   'only',
#   'some,',
#   'not',
#   'less',
#   'been',
#   'been',
#   'waited',
#   'been',
#   'sometimes',
#   'no',
#   'them,',
#   'never',
#   'not',
#   "traitor's",
#   'been',
#   'the',
#   'existed',
#   'done',
#   'handled',
#   'to',
#   'done',
#   'been',
#   'any',
#   'finally',
#   'called'],
#  'no': ['Greek',
#   'accident,',
#   'part',
#   'way',
#   'means',
#   'means',
#   'doubt,',
#   'such',
#   'one,',
#   'one',
#   'one',
#   'doubt',
#   'force—seems',
#   'more',
#   'means',
#   'more',
#   'doubt',
#   'critical',
#   'sign'],
#  'Greek': ['prose', 'criticism,', 'and', 'Romance.', 'original', 'original)'],
#  'fiction': ['till', 'that', 'generally', 'in'],
#  'till': ['a', 'the', 'the', 'the'],
#  'time': ['long', 'indeed,', 'a', 'is', 'when'],
#  'long': ['subsequent', 'before', 'since', 'time.'],
#  'subsequent': ['to'],
#  'to': ['the',
#   'say',
#   '"tell',
#   'know',
#   'do',
#   'Lucian',
#   'think',
#   'be',
#   'conquer',
#   'survey,',
#   'Eustathius',
#   'them',
#   'which',
#   'correspond',
#   'a',
#   'be',
#   'the',
#   'come',
#   'close',
#   'debate',
#   'Things',
#   'date',
#   'their',
#   'homiletic',
#   'lead',
#   'isolation',
#   'a',
#   'deal',
#   'the',
#   'frustrate',
#   'be',
#   'be',
#   'the',
#   'a',
#   'set',
#   'his',
#   'make',
#   'dramatic',
#   'the',
#   'supply',
#   'set',
#   'get',
#   'ignorance,',
#   'question',
#   'Defoe.',
#   'face.',
#   'sort.',
#   'have',
#   'work',
#   'its',
#   'Beryn',
#   'no',
#   'run',
#   'answer',
#   'our',
#   'this',
#   'be',
#   'be',
#   'even',
#   'obtain.',
#   'have',
#   'have',
#   'deprive',
#   'have',
#   'say',
#   'have',
#   'do',
#   'satisfy',
#   'produce',
#   'drowning',
#   'Grimsby.',
#   'rid',
#   'the',
#   'have',
#   'rescue',
#   'the',
#   'develop',
#   'one',
#   'himself.',
#   'have',
#   'do)',
#   'buyers.',
#   'the',
#   'if',
#   'the',
#   'possess',
#   'have',
#   'be',
#   'spoil.',
#   'by',
#   'be',
#   'get',
#   'take',
#   'the',
#   'whom',
#   'do',
#   'Chrestien,',
#   'the',
#   'conceive',
#   'write',
#   'interpret',
#   'busy',
#   'Geoffrey',
#   'tell',
#   'Malory',
#   'turn',
#   'the',
#   'the'],
#  'Christian': ['era,'],
#  'era,': ['and'],
#  'nothing': ['in', 'at', 'in', 'in'],
#  'Latin': ['at', 'before', 'though', 'work,'],
#  'all': ['except',
#   'stories,',
#   'cases,',
#   'doubt',
#   'the',
#   'in',
#   'Anglo-Saxon)',
#   'in',
#   'matter',
#   'are',
#   'in',
#   'perhaps,',
#   'the',
#   'their',
#   'minor',
#   'of',
#   'in'],
#  'except': ['the', 'the', 'by'],
#  'fragments': ['of', 'aside,', 'as', 'of'],
#  'Petronius': ['and'],
#  'romance': ['of', 'of', 'or', 'and', 'and', 'there', 'in', 'from'],
#  'Apuleius.': ['But'],
#  'But': ['it',
#   'otherwise',
#   'as',
#   'these',
#   'let',
#   'the',
#   'there',
#   'we',
#   'the',
#   'the',
#   'in',
#   'Horn',
#   'fiction,',
#   'it',
#   'in',
#   'at',
#   'before'],
#  'it': ['can',
#   'is',
#   'is',
#   'is',
#   'had',
#   'is',
#   'has',
#   'is,',
#   'may',
#   'falls',
#   'is',
#   'is',
#   'is',
#   'would',
#   'be',
#   'deals',
#   'is',
#   'is',
#   'has',
#   'more',
#   'or',
#   'up.',
#   'has',
#   'is.',
#   'has',
#   'much',
#   'is',
#   'really',
#   'are',
#   'up.',
#   'remembered,',
#   'be',
#   'into',
#   'in',
#   'is',
#   'is',
#   'seems',
#   'in',
#   'is',
#   'in',
#   'justice',
#   'happens,',
#   'full',
#   'is',
#   'was',
#   'is',
#   'is',
#   'as',
#   'was',
#   'does',
#   'has',
#   'would',
#   'is'],
#  'can': ['be',
#   'tell',
#   'only',
#   'want',
#   'use,',
#   'miss',
#   'matter',
#   'properly',
#   'require',
#   'speak'],
#  'very': ['momentous',
#   'well',
#   'little',
#   'numerous',
#   'class:',
#   'accomplished,',
#   'debatable',
#   'uncertain:',
#   'early:',
#   'legends,',
#   'small',
#   'far',
#   'fragments',
#   'old',
#   'different',
#   'exalted',
#   'few',
#   'small',
#   'considerable,',
#   'many',
#   'abundant',
#   'large',
#   'much',
#   'obvious',
#   'different;',
#   'infancy',
#   'little'],
#  'momentous': ['fact,'],
#  'fact,': ['that,', 'when', 'one'],
#  'that,': ['from', 'though', 'in', 'where'],
#  'from': ['the',
#   'Longus',
#   'the',
#   'a',
#   'which',
#   'another',
#   'the',
#   'being',
#   'shipwreck,',
#   'style,',
#   'this',
#   'each',
#   'Dr.',
#   'its',
#   'Havelok',
#   'the',
#   'national',
#   'evidence',
#   'which',
#   'his',
#   'the',
#   'the'],
#  'foundation': ['of'],
#  'criticism,': ['"Imitation,"'],
#  '"Imitation,"': ['that'],
#  'say': ['"Fiction"', 'that,', 'the'],
#  '"Fiction"': ['(for'],
#  '(for': ['it'],
#  'neither': ['more'],
#  'more': ['nor',
#   'than',
#   'famous',
#   'or',
#   'than',
#   'fully',
#   'clearly',
#   'like',
#   'developed',
#   'human',
#   'remarkable',
#   'poetical',
#   'episodic',
#   'to',
#   'and',
#   'cut',
#   'perhaps',
#   'masculine',
#   'popular',
#   'than',
#   'than',
#   'conspicuously'],
#  'nor': ['less),'],
#  'less),': ['was'],
#  'was': ['regarded',
#   'a',
#   'to',
#   'probably',
#   'hardly',
#   'to',
#   'an',
#   'no',
#   'Romance.',
#   'prose',
#   'not',
#   'not',
#   'the',
#   'the',
#   'not',
#   'the'],
#  'regarded': ['as'],
#  'as': ['not',
#   'the',
#   'early',
#   '"before',
#   'those',
#   'well',
#   'supernatural:',
#   'a',
#   'an',
#   "Apollonius'",
#   'such.',
#   'that',
#   'to',
#   'well',
#   'across',
#   'Daphnis',
#   'the',
#   'admirably,',
#   'some',
#   'if',
#   'a',
#   'a',
#   'long',
#   'to',
#   'far',
#   'the',
#   'the',
#   'regards',
#   'now—the',
#   'vieux',
#   'not',
#   'infants;',
#   'his',
#   'a',
#   'the',
#   'has',
#   'big',
#   'varied',
#   'any',
#   'one',
#   'a',
#   'of',
#   'it',
#   'has',
#   'being',
#   'to',
#   'his',
#   'it',
#   'we',
#   'introductions,',
#   'little',
#   'in',
#   'we'],
#  'not': ['merely',
#   'seem',
#   'much',
#   'only',
#   'certainly,',
#   'very',
#   'very',
#   'of',
#   'in',
#   'with',
#   'always',
#   'least',
#   'despicable',
#   'doubt',
#   'told',
#   'in',
#   'known',
#   'in',
#   'on',
#   'ready.',
#   'lie',
#   'very',
#   'read',
#   'so',
#   'haphazard',
#   'very',
#   'very',
#   'occupy',
#   'seem',
#   'a',
#   'then,',
#   'the',
#   'quite',
#   'a',
#   'unnatural',
#   'neglected,',
#   'avail',
#   'so',
#   'entirely',
#   'seem',
#   'to',
#   'unpardonable',
#   'consummate,',
#   'to',
#   'surprising',
#   'only',
#   'certainly',
#   'only',
#   'found',
#   'unimportant)'],
#  'merely': ['the'],
#  'inseparable': ['but'],
#  'but': ['the',
#   'the',
#   'its',
#   'distinctly',
#   'that',
#   'what',
#   'with',
#   'with',
#   'substantive—prose',
#   'attempted',
#   'not',
#   'enough',
#   'they',
#   'remarkably',
#   'there',
#   'bolder',
#   'a',
#   'again',
#   'they',
#   'partly',
#   'this',
#   'they',
#   'in',
#   'it',
#   'disappointing.',
#   'the',
#   'is',
#   'rather'],
#  'constituent': ['property'],
#  'property': ['of'],
#  'poetry,': ['even', 'by'],
#  'even': ['though',
#   'later',
#   'many,',
#   'novel.',
#   'among',
#   'Dr.',
#   'the',
#   'without',
#   'Anglo-Saxon',
#   'a',
#   'worked',
#   'that—a',
#   'though'],
#  'those': ['who', 'of', 'who', 'who', 'about'],
#  'who': ['held',
#   'is',
#   'spied',
#   'would',
#   'exclude',
#   'believe',
#   'has',
#   'has',
#   'will',
#   'is',
#   'preceded',
#   'should',
#   'should',
#   'is',
#   'ascertains',
#   'may',
#   'shelters',
#   'have',
#   'would',
#   'can',
#   'have'],
#  'held': ['this'],
#  'this': ['were',
#   'youngest',
#   'very',
#   'fail',
#   'mixture',
#   'in',
#   'score.',
#   'department',
#   'matters,',
#   'the',
#   'affection',
#   'point—not',
#   'flash'],
#  'were': ['doubtful', 'ready', 'sure', 'not.', 'not'],
#  'doubtful': ['whether'],
#  'whether': ['poetry', 'the', 'in'],
#  'poetry': ['must', 'to'],
#  'must': ['necessarily',
#   'come',
#   'have',
#   'contract',
#   'mix',
#   'now',
#   'carry',
#   'have'],
#  'necessarily': ['be'],
#  'verse.': ['It', 'In'],
#  'another': ['fact', 'characteristic', 'branch'],
#  'fact': ['of', 'the', 'it', 'the', 'they'],
#  'greatest': ['importance', 'of', 'and', 'amount'],
#  'importance': ['that', 'of', 'than'],
#  'ancients': ['who,', 'revolted', 'could'],
#  'who,': ['in'],
#  'other': ['forms',
#   'essentially',
#   'two',
#   'world.',
#   'hand,',
#   'foretellings',
#   'age',
#   'knights,',
#   'parts',
#   'or'],
#  'forms': ['than', 'in'],
#  'than': ['deliberate',
#   'framed',
#   'a',
#   'in',
#   'The',
#   'Richardson;',
#   'Fielding.',
#   'if',
#   'the',
#   'in',
#   'any',
#   'drama,',
#   'Havelok',
#   'in',
#   'with',
#   'Malory'],
#  'deliberate': ['prose'],
#  'try': ['to'],
#  '"tell': ['a'],
#  'story,"': ['do'],
#  'do': ['not', 'it.', 'even', 'this', 'not', 'with', 'without', 'it', 'it;'],
#  'seem': ['to', 'to', 'to', 'always', 'to', 'to'],
#  'know': ['very', 'the'],
#  'well': ['how', 'as', 'as', 'known'],
#  'how': ['to', 'Livy', 'to'],
#  'it.': ['The', 'To', 'Perhaps', '"And'],
#  'The': ['Odyssey',
#   'conquered',
#   'opinion',
#   'beginnings',
#   'Vision',
#   'jejuneness',
#   'very',
#   'same',
#   'second,',
#   'same',
#   'Ruin',
#   'Last',
#   'Complaint',
#   'consciences',
#   'present',
#   'separation',
#   'ancients',
#   'Middle',
#   'quality',
#   'Matière',
#   'preliminary',
#   '"off"-branches',
#   'execrable',
#   'love-stories',
#   'story,',
#   'original',
#   'Arthour',
#   'pure',
#   'Scots'],
#  'Odyssey': ['is,', 'itself'],
#  'is,': ['indeed,', 'though', 'for', 'as'],
#  'indeed,': ['one', 'when'],
#  'stories,': ['it'],
#  'original': ['romance', 'of', 'handling', 'for', 'sources'],
#  'West;': ['but'],
#  'Iliad,': ['though'],
#  'magnificent': ['poem,'],
#  'poem,': ['is'],
#  'much': ['of',
#   'more',
#   'more',
#   'better',
#   'or',
#   'into',
#   'of',
#   'later',
#   'written',
#   'less'],
#  'story.': ['Herodotus', 'But'],
#  'Herodotus': ['can'],
#  'tell': ['one,', 'the', 'with'],
#  'if': ['anybody',
#   'it',
#   'not',
#   'dialogue',
#   'not',
#   'not',
#   'he',
#   'not',
#   'they',
#   'sometimes',
#   'Arthur',
#   'anybody',
#   'not',
#   'Thomas',
#   'not'],
#  'anybody': ['can,', 'with', 'is'],
#  'can,': ['and'],
#  'Plato': ['(or'],
#  '(or': ['Socrates)'],
#  'Socrates)': ['evidently'],
#  'evidently': ['could'],
#  'could': ['have', 'do', 'do', 'have'],
#  'done': ['so', 'so', 'it'],
#  'so': ['if',
#   'both',
#   'do',
#   'good,',
#   'frequently.',
#   'far',
#   'late',
#   'that',
#   'forth,',
#   'lazy',
#   'timid',
#   'far',
#   'with',
#   'great',
#   'very',
#   'if',
#   'early.',
#   'forth,'],
#  'had': ['lain', 'all', 'not', 'been', 'of'],
#  'lain': ['in'],
#  'his': ['way:',
#   'story',
#   'chances',
#   'friend',
#   'wooing',
#   'own',
#   'ground',
#   'genius',
#   'rights,',
#   'tutor,',
#   'murderer,',
#   'head;',
#   'crime',
#   'own',
#   'foster-brethren,',
#   'royalty',
#   'head',
#   'companions',
#   'kind)',
#   'faithless',
#   'having',
#   'attributed',
#   'works,',
#   'most'],
#  'way:': ['while'],
#  'while': ['the', 'that'],
#  'Anabasis,': ['though'],
#  'hardly': ['the', 'to', 'care', 'any', 'even'],
#  'Cyropædia,': ['shows'],
#  'shows': ['glimmerings'],
#  'glimmerings': ['in'],
#  'Xenophon.': ['But'],
#  'otherwise': ['we'],
#  'come': ['down', 'to', 'to'],
#  'down': ['to', 'to', 'in'],
#  'Lucian': ['and', 'and', 'was'],
#  'East': ['before', 'and'],
#  'before': ['we', 'the', 'about', 'the', 'those', 'he', 'we'],
#  'find': ['the', 'them', 'little'],
#  'faculty.': ['So,'],
#  'So,': ['too,'],
#  'too,': ['in', 'if', 'discovers', 'though'],
#  'late': ['writers', 'is'],
#  'writers': ['named', 'as'],
#  'named': ['above,'],
#  'above,': ['Ovid'],
#  'Ovid': ['is'],
#  'about': ['the', '400', 'its', 'in', 'Merlin', 'him—is', 'the'],
#  'only': ['person',
#   'two',
#   'its',
#   'one—not',
#   'say',
#   'limited',
#   'fragmentary',
#   'are',
#   'has',
#   'in'],
#  'person': ['who', 'who'],
#  'real': ['story-teller.', 'story—about'],
#  'story-teller.': ['Virgil'],
#  'Virgil': ['makes'],
#  'makes': ['very', 'one'],
#  'little': ['of',
#   'in',
#   'more',
#   'excuse',
#   'interest.',
#   '(though',
#   'it',
#   'skill'],
#  'story': ['in',
#   'too',
#   'of',
#   'which',
#   'and',
#   'to',
#   'of',
#   'of',
#   'of',
#   'and',
#   'than',
#   'the',
#   'in',
#   'of',
#   'of',
#   'of',
#   'itself',
#   'of',
#   'and',
#   'are',
#   'of'],
#  'verse:': ['and'],
#  'shocking': ['to'],
#  'think': ['how', 'Fielding', 'that'],
#  'Livy': ['throws'],
#  'throws': ['away'],
#  'away': ['his'],
#  'chances': ['in'],
#  'prose.': ['No:', 'The', 'Naturally'],
#  'No:': ['putting'],
#  'putting': ['the', 'aside'],
#  'Petronian': ['fragments'],
#  'aside,': ['Lucian'],
#  'Apuleius': ['are', 'an'],
#  'are': ['the',
#   'quite',
#   'very',
#   'very',
#   'still',
#   'not',
#   'in',
#   'indeed',
#   'by',
#   'shown',
#   'the',
#   'really',
#   'widely',
#   'they',
#   'numerous:',
#   'not',
#   'most',
#   'told',
#   'apt',
#   'out',
#   'both',
#   'directly',
#   'is',
#   'concerned,',
#   'of',
#   'of',
#   'of',
#   'capital',
#   'all',
#   'by',
#   'not',
#   'there,',
#   'openings',
#   'what',
#   'distinguished',
#   'on',
#   'no',
#   'the',
#   'well',
#   'shadows',
#   'interesting',
#   'rarely',
#   'wont'],
#  'novelists': ['in', 'inevitably'],
#  'languages': ['before', 'were'],
#  '400': ['A.D.:', 'A.D."'],
#  'A.D.:': ['and'],
#  'aside': ['their'],
#  'their': ['odd',
#   'intrinsic',
#   'touches',
#   'treacherous',
#   'respective',
#   'respective',
#   'complete',
#   'faults,'],
#  'odd': ['coincidence'],
#  'coincidence': ['of'],
#  'subject,': ['it', 'or'],
#  'has': ['to',
#   'been',
#   'been',
#   'yet',
#   'dared',
#   'deceived',
#   'made',
#   'put',
#   'eyes',
#   'eyes',
#   'left',
#   'been',
#   'been',
#   'it.',
#   'a',
#   'been',
#   'ever',
#   'ever',
#   'been',
#   'been',
#   'never',
#   'the',
#   'to'],
#  'remembered': ['that', 'that'],
#  'Syrian': ['Greek'],
#  'African': ['Latin.'],
#  'Latin.': ['The'],
#  'conquered': ['world'],
#  'world': ['was', 'with'],
#  'conquer': ['not'],
#  'its': ['conqueror,',
#   "conqueror's",
#   'verse',
#   'excellence',
#   'allusion',
#   'apparently',
#   'apparently',
#   'narrative',
#   'class,',
#   'present',
#   'completion',
#   'greatest',
#   'dealings'],
#  'conqueror,': ['but'],
#  "conqueror's": ['teacher,'],
#  'teacher,': ['in'],
#  'youngest': ['accomplishment'],
#  'accomplishment': ['of'],
#  'art.': ['It'],
#  'probably': ['in', 'at', 'the', 'be', 'later,', 'younger', 'if'],
#  'cases,': ['if'],
#  'certainly,': ['mixed'],
#  'mixed': ['blood'],
#  'blood': ['that'],
#  'produced': ['the'],
#  'curious': ['development'],
#  'development': ['generally', 'by'],
#  'generally': ['called', 'and'],
#  'called': ['Greek', 'the', 'them,'],
#  'Romance.': ['It', 'These', 'In'],
#  'part': ['of', 'of', 'of', 'of', 'of', 'and'],
#  'our': ['business',
#   'journey.',
#   'proper',
#   'Anglo-Saxon',
#   'own',
#   'proper',
#   'proper',
#   'purpose,',
#   'existing'],
#  'business': ['to'],
#  'survey,': ['in'],
#  'detail,': ['the', 'so'],
#  'numerous': ['but', 'of'],
#  'distinctly': ['interesting', 'remarkable—as'],
#  'interesting': ['compositions', 'enough', 'parts'],
#  'compositions': ['which'],
#  'which': ['range',
#   'is',
#   'we',
#   'the',
#   'the',
#   'are',
#   'the',
#   'was',
#   'is',
#   'style',
#   'has',
#   'we',
#   'had',
#   'they',
#   'with',
#   'have',
#   'we',
#   'no',
#   'is',
#   'produces',
#   'will',
#   'was',
#   'connected',
#   'in',
#   'we',
#   'from',
#   'our',
#   'she',
#   'hardly',
#   'Tristram',
#   'are',
#   'is',
#   'genius'],
#  'range': ['in', 'of', 'of'],
#  'point': ['of'],
#  'authorship': ['from'],
#  'Longus': ['and'],
#  'Heliodorus,': ['probably'],
#  'meeting': ['of'],
#  'fourth': ['and'],
#  'fifth': ['centuries,'],
#  'centuries,': ['to'],
#  'Eustathius': ['in'],
#  'twelfth.': ['At'],
#  'At': ['one'],
#  'when': ['we', 'you', 'we', 'he', 'he', 'they'],
#  'may': ['return', 'have', 'look', 'be', 'without', 'take'],
#  'return': ['to'],
#  'them': ['a',
#   'exercising',
#   'upon,',
#   'with—these',
#   'would',
#   'to',
#   'are',
#   'either'],
#  'little,': ['we', 'had'],
#  'shall': ['find'],
#  'exercising': ['direct'],
#  'direct': ['and'],
#  'powerful': ['influence', 'and'],
#  'influence': ['on'],
#  'modern': ['European', 'languages', 'religious', 'times.', 'times'],
#  'both': ['directly', 'very', 'by', 'internal'],
#  'directly': ['and', 'imitated'],
#  'indirectly': ['on'],
#  'English:': ['but'],
#  'good': ['way', 'reading,', 'points,', 'romance', 'story'],
#  'way': ['removed', 'chargeable', 'admirably,', 'as', 'almost', 'that'],
#  'removed': ['from'],
#  'actual': ['beginning',
#   'results—not',
#   'conditions',
#   'turn-out',
#   'stories',
#   'forms',
#   'handling.'],
#  'beginning': ['of', 'does'],
#  'journey.': ['Still,'],
#  'Still,': ['Apollonius'],
#  'Apollonius': ['of', 'of'],
#  'Tyre,': ['which', 'which'],
#  'oldest': ['piece', 'of', 'that'],
#  'piece': ['of', 'is'],
#  'English': ['prose',
#   'in',
#   'fiction',
#   'literature',
#   'versions',
#   'literature.',
#   'romance,',
#   'Text',
#   'hearers.',
#   'usurper.',
#   'form',
#   'form',
#   '(though',
#   'versions,',
#   'Text',
#   'prose'],
#  'have,': ['is', 'whether', 'adds'],
#  'beyond': ['all', 'it,', 'mere', 'dress'],
#  'doubt': ['derived', 'from', '(unless', 'a', 'Celtic;'],
#  'derived': ['ultimately'],
#  'ultimately': ['from'],
#  'class:': ['and'],
#  'class': ['itself', 'of', 'which'],
#  'itself': ['is',
#   'is',
#   'are',
#   'out',
#   'consists',
#   'without',
#   'do',
#   'for',
#   'as',
#   'in'],
#  'immense': ['advance,'],
#  'advance,': ['in'],
#  'novel': ['direction,',
#   'proper',
#   'are',
#   'is',
#   'arising',
#   'involves',
#   'in',
#   'and',
#   'that'],
#  'direction,': ['upon'],
#  'upon': ['anything', 'all,', '"the', 'except'],
#  'anything': ['that', 'so', 'beyond'],
#  'before.': ['It'],
#  'hand': ['essentially'],
#  'essentially': ['a', 'a', 'unconnected'],
#  '"romance': ['of'],
#  'adventure,"': ['and'],
#  '"love-story"—in': ['senses'],
#  'senses': ['to'],
#  'literature': ['to', 'in', 'of', 'have', 'on', 'in'],
#  'correspond': ['in'],
#  'case': ['and', 'of'],
#  'still': ['less',
#   'infinitely',
#   'more',
#   'less',
#   'by',
#   'more',
#   'older',
#   'firmly'],
#  'less': ['in',
#   'anyhow.',
#   'present',
#   'practical',
#   'for',
#   'interest',
#   'importance',
#   'original',
#   'powerful',
#   'sentimental'],
#  'other.': ['Instead'],
#  'Instead': ['of'],
#  'being,': ['like'],
#  'like': ['Lucius', 'the', 'the', 'it'],
#  'Lucius': ['and'],
#  'Golden': ['Ass,', 'Ass'],
#  'Ass,': ['a'],
#  'tissue': ['of'],
#  'stories': ['essentially', 'told', 'of', 'that', 'or', '(as'],
#  'unconnected': ['and', 'or'],
#  'framed': ['by'],
#  'main': ['tale,', 'subject', 'substance,', 'Arthurian'],
#  'tale,': ['it', 'hitched'],
#  'few': ['episodes,',
#   'exceptions',
#   'people',
#   'seem',
#   'patterns;',
#   'people',
#   'actually',
#   'are',
#   'of'],
#  'episodes,': ['an'],
#  'example': ['of', 'of'],
#  'romantic': ['unity'],
#  'unity': ['throughout,'],
#  'throughout,': ['with'],
#  'with': ['definite',
#   'our',
#   'barbarian',
#   'possible',
#   'actual',
#   'Ancient',
#   'the',
#   'a',
#   'the',
#   'which',
#   'good',
#   'the',
#   'a',
#   'the',
#   'any',
#   'Romance.',
#   'Marivaux',
#   'Madame',
#   'each',
#   'any',
#   'the',
#   'the',
#   'the',
#   'a',
#   'Horn,',
#   'the',
#   'the',
#   'the',
#   'indifferent',
#   'those',
#   'the',
#   'British',
#   'Saxons,',
#   'the',
#   'another',
#   'nearly',
#   'the',
#   'Tennyson,'],
#  'definite': ['hero', 'heroine,'],
#  'hero': ['and', 'and'],
#  'heroine,': ['the'],
#  'prominence': ['and'],
#  'latter': ['being', 'and'],
#  'being': ['specially', 'contemptible:', 'so,'],
#  'specially': ['noteworthy.'],
#  'noteworthy.': ['It'],
#  'first': ['division', 'of', 'is', 'part', 'place'],
#  'division': ['of', 'of'],
#  'heroine': ['assumes'],
#  'assumes': ['the'],
#  'position': ['of', 'which'],
#  'protagonist.': ['If'],
#  'If': ['it'],
#  'falls': ['short', 'in'],
#  'short': ['in'],
#  'character,': ['so', 'of'],
#  'later': ['romances', 'and', 'still', 'writers', 'than'],
#  'romances': ['to', 'and', 'of', 'are'],
#  'extent:': ['if'],
#  'dialogue': ['is'],
#  'accomplished,': ['that'],
#  'also': ['was', '(especially'],
#  'thoroughly': ['developed'],
#  'developed': ['till', 'humanity'],
#  'proper': ['came', 'division,', 'subject', 'work'],
#  'came': ['into'],
#  'into': ['being.', 'grooves', 'his', 'slightly'],
#  'being.': ['In'],
#  'In': ['the',
#   'fact',
#   'the',
#   'the',
#   'every',
#   'the',
#   'fact',
#   'the',
#   'these—even',
#   'the'],
#  'divisions,': ['incident'],
#  'incident': ['and', 'and', 'and'],
#  'description,': ['it'],
#  'abundantly': ['furnished.'],
#  'furnished.': ['And,'],
#  'And,': ['above'],
#  'above': ['all,'],
#  'all,': ['the', 'or', 'Havelok'],
#  'Romantic': ['motives,'],
#  'motives,': ['Adventure'],
#  'Adventure': ['and'],
#  'Love,': ['are'],
#  'quite': ['maturely', 'entire', 'such', 'gratuitously', 'unexpected'],
#  'maturely': ['present'],
#  'present': ['in',
#   'writer—the',
#   'in',
#   'writer',
#   "writer's",
#   'purpose,',
#   'English',
#   'writer,',
#   'writer,'],
#  'To': ['pass'],
#  'pass': ['to'],
#  'deluge,': ['and'],
#  'it,': ['and', 'while', 'that', 'has'],
#  'close': ['quarters'],
#  'quarters': ['with'],
#  'division,': ['the'],
#  'origin': ['of'],
#  'Romance': ['itself', '(even', 'for'],
#  'debatable': ['subject,'],
#  'or': ['rather',
#   'leavening',
#   'even',
#   'Transition',
#   'less',
#   'additions,',
#   'even',
#   'with',
#   'at',
#   'mother',
#   'at',
#   'more',
#   'the',
#   'can',
#   'at',
#   'verse.',
#   'so',
#   'daunted',
#   'difficult',
#   'indiscriminate',
#   'stories',
#   'family.',
#   'Lovelich,',
#   'nearly',
#   'with',
#   'motives.',
#   'scornful',
#   'both',
#   'most',
#   'even',
#   'at',
#   'spoilt',
#   'in',
#   'French,',
#   'out-lying',
#   'rather',
#   'the',
#   'Latin;',
#   'prose.',
#   'Lovelich,',
#   'transverses—has,'],
#  'subject': ['which', 'of', 'begin'],
#  'wiser': ['mind'],
#  'mind': ['will'],
#  'will': ['hardly', 'not', 'not', 'yield', 'make', 'teach', 'succeed,'],
#  'care': ['to'],
#  'debate': ['much.'],
#  'much.': ['The'],
#  'opinion': ['of', 'are'],
#  'writer—the': ['result,'],
#  'result,': ['at'],
#  'least,': ['of', 'utilised'],
#  'many': ["years'", 'representatives', 'who'],
#  "years'": ['reading'],
#  'reading': ['and', 'and'],
#  'thought—is': ['that'],
#  'result': ['of', 'was', 'of'],
#  'marriage': ['of'],
#  'older': ['East', 'Danish'],
#  'newer': ['(non-classical)'],
#  '(non-classical)': ['West'],
#  'West': ['through'],
#  'through': ['the'],
#  'agency': ['of'],
#  'spread': ['of', 'of'],
#  'Christianity': ['and', 'proceeded'],
#  'growth': ['and'],
#  'diffusion': ['of'],
#  '"Saint\'s': ['Life."'],
#  'Life."': ['The'],
#  'beginnings': ['of'],
#  'Hagiology': ['itself'],
#  'uncertain:': ['but'],
#  'certain': ['is', 'of', 'common-sense'],
#  'they': ['are',
#   'are',
#   'show',
#   'who',
#   'actually',
#   'mostly',
#   'have',
#   'are',
#   'had',
#   'would',
#   'really',
#   'have',
#   'are',
#   'give',
#   'are',
#   'began'],
#  'early:': ['and'],
#  'amalgamation': ['or'],
#  'leavening': ['of'],
#  'Roman': ['world'],
#  'barbarian': ['material'],
#  'material': ['proceeded,'],
#  'proceeded,': ['the'],
#  'proceeded': ['likewise.'],
#  'likewise.': ['The'],
#  'Vision': ['of'],
#  'St.': ['Paul—one', 'Margaret', 'Catherine', "Cuthbert's"],
#  'Paul—one': ['of'],
#  'earliest': ['examples', 'with'],
#  'examples': ['and', 'of'],
#  'starter': ['it'],
#  'would': ['seem,',
#   'probably',
#   'make',
#   'almost',
#   'altogether',
#   'indeed',
#   'naturally',
#   'do',
#   'appear,'],
#  'seem,': ['if'],
#  'whole': ['class', 'range', 'universe', 'library'],
#  'sacred': ['Romances,'],
#  'Romances,': ['at'],
#  'rate': ['of'],
#  'large': ['subsection', 'part', 'proportion', 'part'],
#  'subsection': ['devoted'],
#  'devoted': ['to'],
#  'Things': ['after'],
#  'after': ['Death—has'],
#  'Death—has': ['been'],
#  'been': ['put',
#   'expected',
#   'already',
#   'so',
#   'detected',
#   'much',
#   'struck',
#   'said',
#   'called',
#   'very',
#   'popular.',
#   'the',
#   'really',
#   'said,',
#   'one',
#   'able',
#   'sketched,',
#   'said,',
#   'proved—will',
#   'able'],
#  'put': ['as', 'the', 'much', 'these'],
#  'early': ['as', 'Greek', 'vernacular'],
#  '"before': ['400'],
#  'A.D."': ['It'],
#  'difficult': ['to', 'to'],
#  'date': ['such'],
#  'such': ['legends',
#   'as',
#   'mere',
#   'revolt',
#   'as',
#   'as',
#   'common-form',
#   'capacities',
#   'early'],
#  'legends': ['as', 'of', 'as'],
#  'Margaret': ['and'],
#  'Catherine': ['too'],
#  'too': ['early,', 'often', 'much', 'is'],
#  'early,': ['having'],
#  'having': ['regard', 'shown', 'been'],
#  'regard': ['to'],
#  'intrinsic': ['indications:'],
#  'indications:': ['and'],
#  'vast': ['cycle'],
#  'cycle': ['of', 'there'],
#  'Our': ['Lady,', 'Middle'],
#  'Lady,': ['though'],
#  'later,': ['must', 'and'],
#  'begun': ['long'],
#  'ready': ['for', 'for'],
#  'for': ['it,',
#   'us,',
#   'anything;',
#   'something',
#   'the',
#   '"business."',
#   'anything',
#   'generalities',
#   'controversy;',
#   'ignorance',
#   'the',
#   'what',
#   'our',
#   'English',
#   'the',
#   'development',
#   'digression,',
#   'subscribers,',
#   'the',
#   'the',
#   'every',
#   'disbelieving',
#   'a',
#   'that',
#   'its',
#   'the'],
#  'Cross': ['should'],
#  'should': ['be', 'be', 'be', 'have', 'have', 'have'],
#  'earlier': ['still.', 'moderns,', 'English', 'versions', 'forms—the'],
#  'still.': ['And', 'Whether'],
#  'And': ['let', 'when', 'the', 'the'],
#  'let': ['it', 'anybody', 'us'],
#  'these': ["Saints'",
#   'very',
#   'last',
#   'faculties',
#   'Melchisedecs',
#   'originals',
#   'the',
#   'as',
#   'two',
#   'two',
#   'earlier',
#   'two'],
#  "Saints'": ['Lives,', 'Lives', 'Lives—best'],
#  'Lives,': ['which'],
#  'infinitely': ['good'],
#  'reading,': ['are'],
#  'confined': ['to'],
#  'homiletic': ['necessities.'],
#  'necessities.': ['The'],
#  'jejuneness': ['and'],
#  'woodenness': ['from'],
#  'religious': ['story'],
#  'often': ['suffers'],
#  'suffers': ['are'],
#  'chargeable': ['upon'],
#  'many,': ['of'],
#  'them.': ['They', 'As', 'Nor', 'It', 'What', 'So', 'But'],
#  'They': ['have', 'were', 'are', 'are'],
#  'widest': ['range'],
#  'incident—natural': ['as'],
#  'supernatural:': ['their'],
#  'touches': ['of', 'in'],
#  'nature': ['are'],
#  'indeed': ['extended', 'from', 'be', 'must'],
#  'extended': ['far'],
#  'far': ['beyond', 'indeed', 'less', 'as', 'as', 'as', 'greater'],
#  'mere': ['incident.',
#   'story',
#   'fragments',
#   'fashion,',
#   'sequence',
#   'episode',
#   'shadow;'],
#  'incident.': ['Purely'],
#  'Purely': ['comic'],
#  'comic': ['episodes', 'capabilities'],
#  'episodes': ['are', 'and'],
#  'means': ['wanting:', 'ineffectual', 'wasted', 'of'],
#  'wanting:': ['and'],
#  'these,': ['like'],
#  'parallel': ['passages'],
#  'passages': ['in', 'such', 'in'],
#  'dramatising': ['of'],
#  'legends,': ['were'],
#  'sure': ['to'],
#  'lead': ['to'],
#  'isolation': ['of'],
#  'them,': ['and', 'the', 'are', 'the', 'of', 'to'],
#  'secular': ['continuation.'],
#  'continuation.': ['But,'],
#  'But,': ['once'],
#  'once': ['more,'],
#  'more,': ['we'],
#  'contract': ['the'],
#  'sweep,': ['and'],
#  'quicken': ['the'],
#  'pace': ['to'],
#  'deal': ['not', 'mainly'],
#  'possible': ['origins,', 'faculty'],
#  'origins,': ['but'],
#  'results—not': ['with'],
#  'Ancient': ['or'],
#  'Transition': ['literature,'],
#  'literature,': ['but'],
#  'department': ['first', 'of', 'of'],
#  'then,': ['with', 'be'],
#  'third': ['and', 'argument,'],
#  'last': ['narrowing,', 'distinctly', 'two', 'forty', 'part'],
#  'narrowing,': ['to'],
#  'small': ['surviving', 'number'],
#  'surviving': ['amount,'],
#  'amount,': ['and'],
#  'almost': ['completely', 'suffice', 'entirely,', 'all', 'equally'],
#  'completely': ['second-hand'],
#  'second-hand': ['character,'],
#  'Anglo-Saxon': ['literature', 'wreckage.', 'poetry,', 'original'],
#  'combined': ['to'],
#  'frustrate': ['what'],
#  'expected': ['from'],
#  'characteristic': ['of', 'unifying'],
#  'it—the': ['unusual'],
#  'unusual': ['equality'],
#  'equality': ['of'],
#  'verse': ['and', 'division', 'because', 'or'],
#  'departments.': ['We'],
#  'We': ['have'],
#  'one—not': ['quite'],
#  'entire': ['but'],
#  'substantive—prose': ['tale'],
#  'tale': ['in', 'of', 'that'],
#  'Anglo-Saxon,': ['the'],
#  'version': ['of'],
#  'famous': ['story', 'telling', 'story'],
#  'afterwards': ['declined'],
#  'declined': ['by'],
#  'Chaucer,': ['but'],
#  'attempted': ['by'],
#  'friend': ['and', 'also;'],
#  'contemporary': ['Gower,'],
#  'Gower,': ['and'],
#  'enshrined': ['in'],
#  'most': ['certain',
#   'honestly',
#   'complex,',
#   'of',
#   'are',
#   'numerous',
#   'old-fashioned,',
#   'spirited',
#   'poetical',
#   'analytic',
#   'picturesque',
#   'learned',
#   'characteristic',
#   'interesting',
#   'attention.',
#   'effective'],
#  'Shakespearean': ['"doubtfuls,"', 'or'],
#  '"doubtfuls,"': ['Pericles.'],
#  'Pericles.': ['It'],
#  'honestly': ['gives'],
#  'gives': ['itself', 'scope'],
#  'out': ['as', 'of', 'of', 'of', 'of', 'all', 'in', 'as'],
#  'translation': ['(no'],
#  '(no': ['doubt'],
#  'there': ['was',
#   'is',
#   'is',
#   'is',
#   'was',
#   'is',
#   'is',
#   'is',
#   'are',
#   'is',
#   'is',
#   'is',
#   'is',
#   'is'],
#  'original)': ['and'],
#  'deals': ['briefly'],
#  'briefly': ['with'],
#  'subject.': ['But', 'Few'],
#  'narrative': ['style', 'portions', 'and', '(not', 'side,', 'as'],
#  'style': ['it', 'is'],
#  'contemptible:': ['and'],
#  "Apollonius'": ['escape'],
#  'escape': ['from'],
#  'shipwreck,': ['and'],
#  'wooing': ['of'],
#  'daughter': ['of'],
#  'Arcestrates,': ['there'],
#  'something': ['which', 'that'],
#  'different': ['from', 'from', 'keys,', 'as'],
#  'style,': ['and'],
#  'always': ['found', '(perhaps'],
#  'found': ['in', 'here;', 'for'],
#  'company—that': ['faculty'],
#  'faculty': ['of', 'is', 'of', 'and'],
#  'telling': ['a', 'of'],
#  'already': ['referred'],
#  'referred': ['to.', 'to'],
#  'to.': ['Nor'],
#  'Nor': ['does', 'in'],
#  'does': ['this', 'it', 'not', 'not', 'not', 'not', 'add'],
#  'fail': ['in'],
#  'portions': ['of'],
#  'Lives': ['and'],
#  'Homilies,': ['especially'],
#  'especially': ["Aelfric's,", 'in'],
#  "Aelfric's,": ['which'],
#  'possess;': ['in'],
#  'remarkable—as': ['where'],
#  'where': ['Aelfric', 'character', 'he'],
#  'Aelfric': ['tells'],
#  'tells': ['the', 'what'],
#  'monk': ['who'],
#  'spied': ['on'],
#  "Cuthbert's": ['seaside'],
#  'seaside': ['devotions.'],
#  'devotions.': ['The'],
#  'same': ['faculty', 'faculties', 'path', 'token;'],
#  'observable': ['in'],
#  'work,': ['not'],
#  "Bede's": ['still'],
#  'Caedmon': ['story,'],
#  'story,': ['and', 'especially', 'could'],
#  'vision': ['of'],
#  'world.': ['But'],
#  'faculties': ['have', 'reappear'],
#  'better': ['chance', 'than'],
#  'chance': ['of'],
#  'exhibiting': ['themselves'],
#  'themselves': ['in', 'within', 'told', 'out', 'about'],
#  'wreckage.': ['Beowulf'],
#  'Beowulf': ['itself', 'may'],
#  'consists': ['of'],
#  'first-rate': ['story'],
#  'second-rate': ['but'],
#  'despicable': ['tale,'],
#  'hitched': ['together'],
#  'together': ['more'],
#  'anyhow.': ['The'],
#  'second,': ['with'],
#  'points,': ['is,'],
#  'us,': ['negligible:'],
#  'negligible:': ['the'],
#  '"yarn"': ['of'],
#  'primest': ['character.'],
#  'character.': ['One', 'You'],
#  'look': ['back'],
#  'back': ['to'],
#  'without': ['finding', 'undue', 'father', 'making', 'violence,', 'the'],
#  'finding': ['anything'],
#  'good,': ['except'],
#  'adventures': ['of', 'of', 'in', 'concerning', 'of'],
#  'Ass': ['which'],
#  'story-work': ['of'],
#  'mightiest': ['literatures'],
#  'literatures': ['behind'],
#  'behind': ['them.'],
#  'As': ['literature', 'a'],
#  'hand,': ['Beowulf'],
#  'overpraised:': ['it'],
#  'frequently.': ['But'],
#  'slightest': ['faculty'],
#  '"conveyance"': ['tell'],
#  'tolerably': ['receptive'],
#  'receptive': ['audience,'],
#  'audience,': ['and'],
#  'he': ['will',
#   'is',
#   'meddles',
#   'has',
#   'would',
#   'is',
#   'finally',
#   'himself',
#   'does',
#   'sees',
#   'failed,',
#   'is',
#   'wrote,',
#   'also,'],
#  '(unless': ['he'],
#  'fool': ['enough'],
#  'enough': ['to', 'to', 'for', 'in'],
#  'set': ['the', 'them', 'down', 'them', 'adrift'],
#  'effect': ['down'],
#  'own': ['gifts', 'mediæval', 'head', 'family'],
#  'gifts': ['and'],
#  'graces)': ['about'],
#  'excellence': ['as'],
#  'such.': ['There'],
#  'There': ['is', 'are', 'is', 'is'],
#  'character—not': ['much,'],
#  'much,': ['but'],
#  'make': ['it', 'our', 'her'],
#  'adventure—and': ['adventure'],
#  'adventure': ['enough'],
#  'anything;': ['there'],
#  'ineffectual': ['speech—even'],
#  'speech—even': ['dialogue—of'],
#  'dialogue—of': ['a'],
#  'kind:': ['and'],
#  'some': ['effective',
#   'other',
#   'one',
#   'tough',
#   'of',
#   'pleasantly',
#   'century',
#   'of',
#   'way',
#   'places',
#   'quite',
#   'of',
#   'cases'],
#  'effective': ['and', 'passages'],
#  'picturesque': ['description.', 'novelist'],
#  'description.': ['The'],
#  'reappear': ['in'],
#  'Waldhere': ['and'],
#  '"Finnsburgh"': ['fight:'],
#  'fight:': ['but'],
#  'shown': ['much', 'prowess'],
#  'fully': ['in'],
#  'Lives—best': ['of'],
#  'Andreas,': ['no'],
#  'doubt,': ['but'],
#  'remarkably': ['also', 'with'],
#  '(especially': ['considering'],
#  'considering': ['the'],
#  'slender': ['amount'],
#  'amount': ['of', 'of'],
#  '"happenings")': ['in'],
#  'Guthlac': ['and'],
#  'Juliana.': ['In'],
#  'sort': ['of', 'of', 'of'],
#  'approximation': ['which'],
#  'show': ['to'],
#  'dramatic': ['narrative', 'way', 'way'],
#  'exceptions': ['is'],
#  'classics,': ['foretell'],
#  'foretell': ['much'],
#  'clearly': ['and'],
#  'certainly': ['than', 'English.', 'now'],
#  'foretellings': ['which'],
#  'detected': ['in'],
#  'future': ['achievements'],
#  'achievements': ['of'],
#  'fiction.': ['The'],
#  'Ruin': ['(the'],
#  '(the': ['finest'],
#  'finest': ['thing'],
#  'thing': ['perhaps'],
#  'perhaps': ['in', 'including', 'more', 'than'],
#  'Anglo-Saxon)': ['is'],
#  'background': ['study'],
#  'study': ['for'],
#  'Last': ['Days'],
#  'Days': ['of'],
#  'Pompeii:': ['and'],
#  'Complaint': ['of'],
#  'Deor,': ['in'],
#  'allusion': ['to'],
#  'smith': ['Weland'],
#  'Weland': ['and'],
#  'others,': ['makes', 'and', 'are'],
#  'sorry': ['that'],
#  'historian': ['of', 'of'],
#  'decadent': ['though'],
#  'agreeable': ['Wayland'],
#  'Wayland': ['the'],
#  'Smith,': ['had'],
#  'told': ['us', 'that', 'in', 'to', 'that'],
#  'us': ['the', 'turn', 'as'],
#  'now': ['left', 'attack.', 'never'],
#  'left': ['untold.', 'us'],
#  'untold.': ['A'],
#  'A': ['crowd'],
#  'crowd': ['of'],
#  'fantastic': ['imaginings'],
#  'imaginings': ['or'],
#  'additions,': ['to'],
#  'supply': ['the', 'of'],
#  'substance,': ['and'],
#  'common-sense': ['grasp'],
#  'grasp': ['of'],
#  'conditions': ['and'],
#  'circumstances': ['to'],
#  'upon,': ['and'],
#  'contrast': ['them'],
#  'with—these': ['are'],
#  'requirements': ['of'],
#  'Fiction': ['in'],
#  'life': ['and'],
#  'You': ['must', 'must', 'have'],
#  'mix': ['prose'],
#  'get': ['a', 'themselves', 'a'],
#  'novel.': ['The', 'Of'],
#  'consciences': ['of'],
#  'revolted': ['from'],
#  'mixture': ['of', 'of'],
#  'kinds;': ['but'],
#  'revolt': ['in'],
#  'moderns,': ['and'],
#  'mediæval': ['forefathers.', 'composition.'],
#  'forefathers.': ['So'],
#  'So': ['few', 'too'],
#  'people': ['are', 'very', 'know', 'have'],
#  'really': ['acquainted', 'straying', 'decisive', 'does', 'have', 'improved'],
#  'acquainted': ['with'],
#  '(even': ['in'],
#  'English),': ['or'],
#  'undue': ['presumption'],
#  'presumption': ['set'],
#  'part,': ['if'],
#  'whole,': ['to'],
#  'ignorance,': ['a'],
#  'doctrine': ['and'],
#  'attack.': ['This'],
#  'This': ['is', 'usurper', 'appears'],
#  'widely': ['separated'],
#  'separated': ['from'],
#  'each': ['other;', 'other'],
#  'other;': ['and'],
#  'straying': ['out'],
#  'ground': ['if'],
#  'meddles': ['with'],
#  'These': ['are'],
#  'begin': ['with'],
#  'Marivaux': ['and'],
#  'Richardson,': ['or'],
#  'Madame': ['de'],
#  'de': ['La', 'geste', 'Rome,', 'Borron,', 'Troyes,'],
#  'La': ['Fayette,'],
#  'Fayette,': ['who'],
#  'exclude': ['Bunyan'],
#  'Bunyan': ['altogether,'],
#  'altogether,': ['and'],
#  'sometimes': ['go', 'rather', 'a'],
#  'go': ['so'],
#  'question': ['the'],
#  'right': ['of'],
#  'entry': ['to'],
#  'Defoe.': ['But'],
#  'counter-arguments': ['are'],
#  'numerous:': ['and'],
#  'suffice': ['by'],
#  'itself.': ['In'],
#  'place': ['the'],
#  'idea': ['of'],
#  'arising': ['so'],
#  'unnatural': ['and', 'repugnance'],
#  'unhistorical:': ['these'],
#  'Melchisedecs': ['without'],
#  'father': ['or', 'is'],
#  'mother': ['are'],
#  'known': ['in', 'to'],
#  'literature.': ['In', 'It'],
#  'second': ['a'],
#  'pedantic': ['insistence'],
#  'insistence': ['on'],
#  'exclusive': ['definition'],
#  'definition': ['of'],
#  'involves': ['one'],
#  'practical': ['inconvenience', 'in'],
#  'inconvenience': ['which'],
#  'among': ['those'],
#  'believe': ['in'],
#  'yet': ['dared', 'there'],
#  'dared': ['to', 'some'],
#  'face.': ['You'],
#  'carry': ['your'],
#  'your': ['wall', 'own'],
#  'wall': ['of'],
#  'partition': ['along'],
#  'along': ['the'],
#  'road': ['as'],
#  'across': ['it:'],
#  'it:': ['and'],
#  'write': ['separate', 'in'],
#  'separate': ['histories'],
#  'histories': ['of'],
#  'Novel': ['and'],
#  'centuries.': ['The'],
#  'writer': ['can', 'who'],
#  'tough': ['adventures'],
#  'history,': ['he', 'national', 'and'],
#  'altogether': ['decline'],
#  'decline': ['this.'],
#  'this.': ['Without'],
#  'Without': ['the'],
#  'help': ['of'],
#  'ants': ['that'],
#  'succoured': ['Psyche'],
#  'Psyche': ['against'],
#  'against': ['Venus'],
#  'Venus': ['that'],
#  'heap': ['would'],
#  'ill': ['to'],
#  'sort.': ['But'],
#  'argument,': ['less'],
#  'appearance': ['but'],
#  'bolder': ['and', 'villain'],
#  'deeper,': ['which'],
#  'decisive': ['of', 'on'],
#  'matter,': ['though'],
#  'seen': ['it'],
#  'taken': ['it'],
#  'up.': ['The', 'Most'],
#  'separation': ['of'],
#  'novel—of': ['the'],
#  'character': ['and', 'and', 'of', 'comes'],
#  'motive—is': ['a'],
#  'mistake': ['logically', 'it', 'to'],
#  'logically': ['and'],
#  'psychologically.': ['It'],
#  'old': ['mistake,'],
#  'mistake,': ['and'],
#  'deceived': ['some'],
#  'elect:': ['but'],
#  'is.': ['It'],
#  'made': ['even', 'people', 'the'],
#  'Dr.': ['Johnson', 'Johnson'],
#  'Johnson': ['think', 'think'],
#  'Fielding': ['shallower'],
#  'shallower': ['than'],
#  'Richardson;': ['and'],
#  'Count': ['Tolstoi'],
#  'Tolstoi': ['is'],
#  'greater': ['analyst', 'creation', 'or', 'story'],
#  'analyst': ['and'],
#  'master': ['of'],
#  'humanity': ['than'],
#  'Fielding.': ['As'],
#  'matter': ['of', 'whether', 'to', 'before'],
#  'you': ['have', 'have', 'have'],
#  'excogitated': ['two'],
#  'human': ['beings', 'and'],
#  'beings': ['out'],
#  'head': ['and', 'to'],
#  'work': ['in', 'and', 'of'],
#  '(not': ['the', 'perhaps'],
#  'dramatic)': ['way,'],
#  'way,': ['you'],
#  'posse,': ['if'],
#  'esse,': ['from'],
#  'apparently': ['simplest', 'most'],
#  'simplest': ['development,'],
#  'development,': ['such'],
#  'Daphnis': ['and'],
#  'Chloe,': ['to'],
#  'complex,': ['such'],
#  'Kreutzer': ['Sonata'],
#  'Sonata': ['or'],
#  'triumphs': ['of'],
#  'Mr.': ['Meredith.', 'Ward.', 'Blackmore,', 'Meredith,'],
#  'Meredith.': ['You'],
#  'started': ['the'],
#  '"Imitation"—the': ['"fiction"—and'],
#  '"fiction"—and': ['tout'],
#  'tout': ['est'],
#  'est': ['là.'],
#  'là.': ['The'],
#  'admirably,': ['though', 'but'],
#  'patterns;': ['in'],
#  'poetical': ['way', 'on', 'parts', 'justice', 'touches'],
#  'again': ['not'],
#  'many.': ['The'],
#  'Middle': ['Ages', 'Ages', 'English'],
#  'Ages': ['lost', 'has'],
#  'lost': ['the'],
#  'entirely,': ['but'],
#  'actually': ['improved', 'obsolete', 'transprosed'],
#  'improved': ['the', 'upon'],
#  'side,': ['and'],
#  'every': ['romance', 'novel', 'possible'],
#  'germ': ['of'],
#  'more;': ['there'],
#  'suggestion': ['and'],
#  'possibility': ['of'],
#  'deserves': ['the'],
#  'Tristram': ['story', 'and', 'is'],
#  'Lancelot': ['cycle', 'and', 'and', 'is'],
#  'things': ['that', 'are'],
#  'romancer': ['of', '(though,'],
#  'novelist': ['of', 'of'],
#  'motive': ['can'],
#  'want': ['or'],
#  'use,': ['till'],
#  'end': ['of'],
#  'world;': ['and'],
#  'Malory': ['(that', 'exercised', 'a', 'himself,', 'actually', 'himself'],
#  '(that': ['"mere'],
#  '"mere': ['compiler"'],
#  'compiler"': ['as'],
#  'pleasantly': ['call'],
#  'him)': ['has', 'herself'],
#  'possibilities': ['of', 'of'],
#  'creation': ['so'],
#  'eyes': ['can', 'for'],
#  'miss': ['them.'],
#  'vehicle': ['was'],
#  'mostly': ['wrote'],
#  'wrote': ['in', 'on', 'only'],
#  'because': ['prose'],
#  'ready.': ['In'],
#  'minor': ['romances', 'legends'],
#  'tales': ['(taking', 'are'],
#  '(taking': ['English'],
#  'versions': ['only)', 'in', 'of'],
#  'only)': ['from'],
#  'Havelok': ['to', 'the', 'is', 'having', 'and'],
#  'Beryn': ['there'],
#  'universe': ['of'],
#  ...}

# %%
# what is most probable next word for "the" --- cat
